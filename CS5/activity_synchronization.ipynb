# %% [markdown]
# # Case Study 5: Activity Synchronization

# %% [markdown]
# ``Pump \& dump" is a shady scheme where the price of a stock is inflated by simulating a surge in buyer interest through false statements (pump) to sell the cheaply purchased stock at a higher price (dump). Investors are vulnerable to this kind of manipulation because they want to act quickly when acquiring stocks that seem to promise high future profits. By exposing investors to information seemingly from different sources in a short period of time, fraudsters create a false sense of urgency that prompts victims to act.
#
# Social media provides fertile grounds for this type of scam. We investigate the effectiveness of our approach in detecting coordinated cryptocurrency pump \& dump campaigns on Twitter. The data was collected using keywords and cashtags (e.g., \$BTC) associated with 25 vulnerable cryptocoins as query terms. We consider both original tweets and retweets because they all add to the stream of information considered by potential buyers. More details on the dataset are found in

# %% [markdown]
# | **Parameter**       | Description       |
# |-----------------------|------------------------------|
# | **Support filter**    | Accounts with < 8 tweets    |
# | **Trace**             | Tweet timestamp             |
# | **Eng. trace**        | 30-minute time intervals    |
# | **Bipartite weight**  | TF-IDF                      |
# | **Proj. weight**      | Cosine similarity           |
# | **Edge filter**       | Keep top 0.5% weights       |
# | **Clustering**        | Connected components        |
# | **Data source**       | DARPA SocialSim             |
# | **Data period**       | Jan 2017--Jan 2019          |
# | **No. accounts**      | 887,239                     |
#
# *Table: Case study 5 summary*

# %% [markdown]
# ## Detection
#
# We hypothesize that coordinated pump \& dump campaigns use software to have multiple accounts post pump messages in close temporal proximity. Tweet timestamps are therefore used as the behavioral trace of the accounts.
# The shorter the time interval in which two tweets are posted, the less likely they are to be coincidental. However, short time intervals result in significantly fewer matches and increased computation time. On the other hand, longer (e.g., daily) intervals produce many false positive matches. To balance between these concerns, we use 30-minute time intervals.
#
# Intuitively, it is likely that any two users would post one or two tweets that fall within any time interval; however, the same is not true for a set of more tweets. To focus on accounts with sufficient support for coordination, we only keep those that post at least eight messages. This specific support threshold value is chosen to minimize false positive matches
#
# The tweets are then binned based on the time interval in which they are posted. These time features are used to construct the bipartite network of accounts and tweet times. Edges are weighted using TF-IDF. Similar to the previous case, the projected account coordination network is weighted by the cosine similarity between the TF-IDF vectors. Upon manual inspection, we found that many of the tweets being shared in this network are not related to cryptocurrencies, while only a small percentage of edges are about this topic. These edges also have high similarity and yield a strong signal of coordination. Thus, we only preserve the 0.5\% of edges with largest cosine similarity

# %% [markdown]
# # Data
# The sample data used in this notebook can be found at [this link](https://drive.google.com/drive/folders/12KmY-mZw_GdwXHoUKcIr1jJvmleGY794?usp=sharing).
#
# To use it, download the file to `CS5/data` folder

# %% [markdown]
# # Helper functions

# %%
import gzip
import os
import numpy as np
import pandas as pd
from sparse_dot_topn import sp_matmul_topn
from tqdm import tqdm
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import Counter, defaultdict
import json
import math


def counters2edges(counter_dict, p1_col, p2_col, w_col):
    # Count how many times each feature co-occurs with each user
    edge = pd.DataFrame.from_records(
        [
            (uid, feature, count)
            for uid, feature_counter in counter_dict.items()
            for feature, count in feature_counter.items()
        ],
        columns=[p1_col, p2_col, w_col],
    )
    return edge


def prepare_content(in_fp, tqdm_desc="parse raw content", tqdm_total=None):
    """
    Parse tweet timestamps from a raw tweet file.
    Tweet timestamps are converted to the nearest 30 minutes
    Note that the fields in here are different from the usual Twitter fields, because this is a anonymized dataset
    i.e., we access the attribute "id_h" instead of "id_str"
    """
    user_features = defaultdict(lambda: defaultdict(Counter))
    n = 0
    for line in tqdm(in_fp, desc=tqdm_desc, total=tqdm_total):
        twt = json.loads(line)

        if "timestamp_ms" in twt:
            try:
                user_id = twt["user"]["id_str_h"]
                # user_id = twt["user"]["id_str"] # Use these fields if run on normal Twitter dataset
                twt_time_str = twt["timestamp_ms"][:-3]
                created_at = int(twt_time_str)
            except:
                continue

            # find min time
            if n == 0:
                min_time = created_at
            # convert the time to the nearest 30 minutes
            if ((created_at - min_time) % 1800) == 0:
                user_features["tweet_time"][user_id][created_at] += 1
            else:
                if created_at < min_time:
                    time_bin = math.ceil((created_at - min_time) / 1800)
                if created_at > min_time:
                    time_bin = math.floor((created_at - min_time) / 1800)
                twt_time = min_time + time_bin * 1800
                user_features["tweet_time"][user_id][twt_time] += 1
            n += 1

    return user_features


def dummy_func(doc):
    return doc


def calculate_interaction(
    edge_df,
    p1_col,
    p2_col,
    w_col,
    node1_col,
    node2_col,
    sim_col,
    sup_col,
    tqdm_total=None,
    tqdm_desc="calculating interaction",
):
    """
    calculate interactions between nodes in partition 1

    input:
        edge_df : dataframe that contains (p1, p2, w)
        p1_col : column name that represent p1, i.e: uid
        p2_col : column name that represent p2 , e.g: time
        w_col : column name that represent weight, if None it's unweighted
        node1_col, node2_col: col after projection, both are uid
        supports: dictionary of userids - post count {p1_node: support}
    return:
        interactions : dict { (p1_node1, p1_node2) : interaction_weight }

    assumption:
        1. non-empty inputs: edge_df
        2. p1_node1 < p1_node2 holds for the tuples in interactions
    """
    user_ids, docs = zip(
        *(
            (p1_node, grp[p2_col].repeat(grp[w_col]).values)
            for p1_node, grp in edge_df.groupby(p1_col)
            if len(grp) > 1
        )
    )

    try:
        tfidf = TfidfVectorizer(
            analyzer="word",
            tokenizer=dummy_func,
            preprocessor=dummy_func,
            use_idf=True,
            token_pattern=None,
            lowercase=False,
            sublinear_tf=True,
            min_df=3,
        )
        docs_vec = tfidf.fit_transform(docs)
    except ValueError:
        tfidf = TfidfVectorizer(
            analyzer="word",
            tokenizer=dummy_func,
            preprocessor=dummy_func,
            use_idf=True,
            token_pattern=None,
            lowercase=False,
            sublinear_tf=True,
            min_df=1,
        )
        docs_vec = tfidf.fit_transform(docs)

    results = sp_matmul_topn(docs_vec, docs_vec.T, top_n=100)

    interactions = pd.DataFrame.from_records(
        [
            (
                u1,
                user_ids[u2_idx],
                sim,
                min(supports[user_ids[u1_idx]], supports[user_ids[u2_idx]]),
            )
            for u1_idx, u1 in enumerate(user_ids)
            for u2_idx, sim in zip(
                results.indices[results.indptr[u1_idx] : results.indptr[u1_idx + 1]],
                results.data[results.indptr[u1_idx] : results.indptr[u1_idx + 1]],
            )
            if u1_idx < u2_idx
        ],
        columns=[node1_col, node2_col, sim_col, sup_col],
    )

    return interactions

# %% [markdown]
# ## Count the number of lines to use progress bar (optional)

# %%
# get number of tweets (this case study uses the same data as CS4)
raw_json_gz = f"data/sample_raw_tweets.json.gz"
# number of lines in the input file
numline_file = f"data/sample_raw_tweets.numline"

# %%
! cat {raw_json_gz} | wc -l > {numline_file}

# %%
numline = int(open(numline_file).read().strip())
numline
# Out:
# 1850502

# %% [markdown]
# # Step 1. Parse json of tweets to a table of user - feature values
#
# Construct a uid - feature - count table from raw tweets
#
# Input: raw tweet.json.gz files
#
# Output: feature parquets
# In this case study, the feature are the timestamps of tweets that a user posted.
# For other case studies, the features can be different. E.g., in case study 4, the features are the tweet IDs that a user retweeted.

# %%
outdir = "results"
if not os.path.exists(outdir):
    os.makedirs(outdir)
# column name of nodes in partite 1 and 2; column name of edge weights
p1_col = "uid"
p2_col = "feature"
w_col = "cnt"

feature = "tweet_time"
# read input
with gzip.open(raw_json_gz, "rb") as in_fp:
    # do work
    user_features = prepare_content(in_fp, tqdm_total=numline)

# write output
edge_df_name = f"{outdir}/{feature}.edge.parquet"
for feature, counter_dict in user_features.items():
    edge_df = counters2edges(counter_dict, p1_col, p2_col, w_col)

    fname = "{}.edge.parquet".format(feature)
    edge_df.to_parquet(edge_df_name)
# Out:
# parse raw content:  32%|███▏      | 600000/1850502 [00:30<01:03, 19571.36it/s]

# %% [markdown]
# ## Let's take a look at the feature dataframe

# %%
edge_df.head()
# Out:
#                       uid     feature  cnt
# 0  Q0uH5xSU0vGCYSd4R_8gJg  1491410045    1
# 1  Q0uH5xSU0vGCYSd4R_8gJg  1491006845    1
# 2  Q0uH5xSU0vGCYSd4R_8gJg  1491237245    1
# 3  Q0uH5xSU0vGCYSd4R_8gJg  1493147045    1
# 4  Q0uH5xSU0vGCYSd4R_8gJg  1503542045    1

# %%
pd.read_parquet(edge_df_name).head()
# Out:
#                       uid     feature  cnt
# 0  Q0uH5xSU0vGCYSd4R_8gJg  1491410045    1
# 1  Q0uH5xSU0vGCYSd4R_8gJg  1491006845    1
# 2  Q0uH5xSU0vGCYSd4R_8gJg  1491237245    1
# 3  Q0uH5xSU0vGCYSd4R_8gJg  1493147045    1
# 4  Q0uH5xSU0vGCYSd4R_8gJg  1503542045    1

# %% [markdown]
# # Step 2. Calculate the similarity between features
#
# We consider each user as a document, and "words" are the feature scores, i.e., time intervals.
# - We first filter out users with lack of support, i.e., those posting less than `sup_thresh = 8`
#
# - We then create a TF-IDF vector for each user, where each dimension is a time interval, and the value is the number of tweets in that time interval.
#
# We output a dataframe with the following columns: `user1, user2, similarity, support`; where each record represents an interaction between `user1` and `user2`; `similarity` is the strength of connections and `support` is the post count of `user1`

# %%
# column name of node1, node2, similarity, support
node1_col = "user1"
node2_col = "user2"
sim_col = "similarity"
sup_col = "support"
sup_thresh = 8
# takes a .parquet file of edge table
# save to output file of interactions with p-values
interaction_file = f"{outdir}/{feature}.interactions.parquet"
outfile = interaction_file
# read input
edge_df = pd.read_parquet(edge_df_name)

if not (len(edge_df) > 0 and np.any(edge_df.groupby(p1_col).size() > 1)):
    raise ValueError(
        "Empty input edge table. Run `prepare_content()` to create edge table first"
    )
else:
    # calculate the support, which is the post count for each user
    supports = edge_df.groupby(p1_col)[w_col].sum().to_dict()
    print("No users: ", len(supports))
    # filter nodes based on support
    supports = {k: v for k, v in supports.items() if v > sup_thresh}
    print(f"No users after filtering with threshold={sup_thresh}: {len(supports)}")
    filtered_nodes = list(supports.keys())
    # remove the nodes with low support from edge_df
    edge_df = edge_df[edge_df[p1_col].isin(filtered_nodes)]

    # calculate similirity between users
    interaction_df = calculate_interaction(
        edge_df, p1_col, p2_col, w_col, node1_col, node2_col, sim_col, sup_col
    )
    # write output
    interaction_df.to_parquet(outfile)
# Out:
# No users:  255999
# No users after filtering with threshold=8: 7832

# %% [markdown]
# # Let's take a look at the interaction df

# %%
interaction_df = pd.read_parquet(interaction_file)
interaction_df.head()
# Out:
#                     user1                   user2  similarity  support
# 0  --ImalkjS1xalfu1Yctubg  rmkPcZpvrs2UwzjM2sClQw    0.079465       13
# 1  --ImalkjS1xalfu1Yctubg  re76DNK1AMl1M1tlGHNR-w    0.086645       10
# 2  --ImalkjS1xalfu1Yctubg  jYGAgiqc2IGYpwXDPIczaA    0.079286       14
# 3  --ImalkjS1xalfu1Yctubg  7JdRlQYUwQVr8e-tgM3nFQ    0.009486       22
# 4  --ImalkjS1xalfu1Yctubg  zWE8_nGEpdzm1xRboFSmeQ    0.088512       11

# %% [markdown]
# # Step 3. Filter low edge weight and create a network
# For case study 5, we apply an weight filter `sim_thresh = 0.995`, i.e., only accounts with similarity >0.995 percentile are considered

# %%
import networkx as nx

# path to input indexed text of tweets
twttext = f"{outdir}/table.by.user.pkl"

# path to output file of the graphml for Gephi visualization
outgraph = f"{outdir}/{feature}.filtered.coord.graphml"
# path to output file of context of each suspicious group
grouptext = f"{outdir}/{feature}filtered.coord.pkl"

# read input parquet file of interaction
interaction_df = pd.read_parquet(interaction_file)

# define the filters
sim_thresh = 0.995

# %%
# apply edge weight filter: 0.995 quantile cosine similarity of TFIDF vectors
interaction_df = interaction_df[
    interaction_df[sim_col] >= interaction_df[sim_col].quantile(sim_thresh)
]
# create a graph object from the interaction table
G = nx.Graph()
for idx, row in interaction_df.iterrows():
    try:
        G.add_edge(
            row[node1_col], row[node2_col], weight=row[sim_col], support=row[sup_col]
        )
    except:
        print(row)
        pass
#  write graph object to file
nx.write_gml(G, outgraph)

# %% [markdown]
# # Note
#
# The above code matches the filtering procedure described in the paper:
# 1. users with low support (few posts) are removed
# 2. tf-idf vectors are calculated
# 3. similarity between tf-idf vectors are calculated, and edges with low similarity are removed.
#
# The results of case study 5 in the paper were obtained by a slightly different ordering of these steps:
# 1. tf-idf vectors are calculated
# 2. similarity between tf-idf vectors are calculated, and edges with low similarity are removed
# 3. users with low support are removed.
#
# The resulting networks are very similar, and the result reported in the paper are not affected by this change.

# %% [markdown]
# # Optional final step: manual inspection
#
# For optional close-reading of the case study, we parse the raw json of tweets to a table of user_id - tweet text and save to file

# %% [markdown]
# ## 1. Save user_id and tweet texts

# %%
#!/usr/bin/env python3
import os
import gzip
import pickle
import ujson as json
from tqdm import tqdm
import networkx as nx

# path to output directory for output randomized edge tables
outdir = "results"
if not os.path.exists(outdir):
    os.makedirs(outdir)


def prepare_content(in_fp, tqdm_desc="parse user tweet", tqdm_total=None):
    # create a dictionary of user_id -> list of tweets by that user
    user_tweets = defaultdict(list)
    for line in tqdm(in_fp, desc=tqdm_desc, total=tqdm_total):
        twt = json.loads(line)
        try:
            user_id = twt["user"]["id_str_h"]
            user_tweets[user_id].append(twt["text_m"])
            # Use these fields if run on normal Twitter dataset
            # user_id = twt["user"]["id_str"]
            # user_tweets[user_id].append(twt["text"])
        except:
            pass
    return user_tweets


# path to output pickle file of tweet table
outfile = f"{outdir}/table.by.user.pkl"


# read input to create a dictionary of user_id -> list of tweets by that user
with gzip.open(raw_json_gz, "rb") as in_fp:
    # do work
    user_tweets = prepare_content(in_fp, tqdm_total=numline)
with open(outfile, "wb") as out_fp:
    # write output
    pickle.dump(user_tweets, out_fp)
# Out:
# parse user tweet:  32%|███▏      | 600000/1850502 [00:24<00:50, 24529.52it/s]

# %% [markdown]
# ### Let's take a look at a few records

# %%
idx = 0
for k, v in user_tweets.items():
    print(k, v)
    idx += 1
    if idx > 5:
        break
# Out:
# Q0uH5xSU0vGCYSd4R_8gJg [' url: https://t.co/9rJOUrrFjs56EKUC7Mx5sg  #3: K-Swiss Ultra-Express Omni N Zapatillas, Hombre  url: https://t.co/08XQ7_X4PM3ErAz3WXhh0g  #valencia #vigo #bilbao', ' url: https://t.co/9rJOUrrFjs56EKUC7Mx5sg  #3: K-Swiss Accomplish II Mesh Omni Fiery - Zapatillas paraâ\x80¦  url: https://t.co/VyDDbaAiRwAmM52jUuLtaw  #valencia #vigo #bilbao', ' url: https://t.co/9rJOUrrFjs56EKUC7Mx5sg  #3: K-Swiss Ultra-Express Omni N Zapatillas, Hombre  url: https://t.co/08XQ7_X4PM3ErAz3WXhh0g  #valencia #vigo #bilbao', ' url: https://t.co/9rJOUrrFjs56EKUC7Mx5sg  #7: Columbia Redmond Mid Leather Omni-Tech, Zapatos de High Riseâ\x80¦  url: https://t.co/udryRnBU7tCeE9EU57oR9g  #valencia #vigo #bilbao  url: https://t.co/-UodBxzGyl5gscXXykuaXw ', ' url: https://t.co/9rJOUrrFjs56EKUC7Mx5sg  |MÃ¡s vendido #1: K-Swiss Accomplish II Mesh Omni Fiery -â\x80¦  url: https://t.co/8p4srGb4IsI9-ZWBJJBY7Q  #valencia #vigo #bilbao  url: https://t.co/MO4-9TF15AkOFh2wzihIAA ', ' url: https://t.co/9rJOUrrFjs56EKUC7Mx5sg  |MÃ¡s vendido #6: K-Swiss Calabasas Mesh Omni Zapatillas, Hombre  url: https://t.co/2H-J3u-7KNzi71RIZizVbg  #valencia #vigo #bilbao', ' url: https://t.co/9rJOUrrFjs56EKUC7Mx5sg  |MÃ¡s vendido #1: K-Swiss Accomplish II Mesh Omni Fiery -â\x80¦  url: https://t.co/8p4srGb4IsI9-ZWBJJBY7Q  #valencia #vigo #bilbao', ' url: https://t.co/9rJOUrrFjs56EKUC7Mx5sg  |MÃ¡s vendido #5: K-Swiss Accomplish II Mesh Omni Fiery -â\x80¦  url: https://t.co/7bm6O95DVY7_rLV6aKpSFA  #valencia #vigo #bilbao  url: https://t.co/sWQAPucgkFE4RwFBddwUDg ', ' url: https://t.co/9rJOUrrFjs56EKUC7Mx5sg  |MÃ¡s vendido #8: K-Swiss Calabasas Mesh Omni Zapatillas, Hombre  url: https://t.co/HihAEdXrCZMmeHv2DIZhiQ  #valencia #vigo #bilbao', ' url: https://t.co/K2sR0S7HBNCTEGMJmw0skA  |MÃ¡s vendido #6: K-Swiss Calabasas Mesh Omni Zapatillas, Hombre  url: https://t.co/8mdmutVfSL6NWrqKZJBSUg  #valencia #vigo #bilbao', ' url: https://t.co/9rJOUrrFjs56EKUC7Mx5sg  |MÃ¡s vendido #9: K-Swiss Accomplish II Mesh Omni Fiery - Zapatillas para hombre, color rojo  url: https://t.co/kczSPK6hBe5NWiPwp6xYWw  #valencia #vigo #bilbao', ' url: https://t.co/9rJOUrrFjs56EKUC7Mx5sg  |MÃ¡s vendido #4: K-Swiss Accomplish II Mesh Omni Fiery - Zapatillas para hombre, color rojo  url: https://t.co/-DE08MV5R4BFv5eTi6EEtQ  #valencia #vigo #bilbao', ' url: https://t.co/9rJOUrrFjs56EKUC7Mx5sg  |MÃ¡s vendido #6: K-Swiss Accomplish II Mesh Omni Fiery - Zapatillas para hombre, color rojo  url: https://t.co/6Qk2O8C8nmYJX4DA7roQCA  #valencia #vigo #bilbao', ' url: https://t.co/9rJOUrrFjs56EKUC7Mx5sg  |MÃ¡s vendido #8: K-Swiss Accomplish II Mesh Omni Fiery - Zapatillas para hombre, color rojo  url: https://t.co/uLHVjbHm6NSKD6O9vI6iiQ  #valencia #vigo #bilbao', ' url: https://t.co/9rJOUrrFjs56EKUC7Mx5sg  #7: ColumbiaBUGABOOT PLUS III OMNI-HEAT - zapatillas de trekking yâ\x80¦  url: https://t.co/FK4usD2x7rDcgsHkGg-0FQ  #valencia #vigo #bilbao', ' url: https://t.co/9rJOUrrFjs56EKUC7Mx5sg  #2: K-Swiss Ultra-Express Omni N - Zapatillas para hombre, colorâ\x80¦  url: https://t.co/1LXBxm1DYwciO2qB8HYBwA  #valencia #vigo #bilbao', ' url: https://t.co/9rJOUrrFjs56EKUC7Mx5sg  #6: K-Swiss Bigshot Light Omni - Zapatillas para hombre, colorâ\x80¦  url: https://t.co/GBPtGg9DsjxaRuSDwigKvw  #valencia #vigo #bilbao', ' url: https://t.co/9rJOUrrFjs56EKUC7Mx5sg  #5: K-Swiss Ultra-Express Omni N Zapatillas, Hombre  url: https://t.co/4e7Ou_F8GoZF68jfv5zfHw  #valencia #vigo #bilbao', ' url: https://t.co/K2sR0S7HBNCTEGMJmw0skA  #5: K-Swiss Calabasas Mesh Omni Zapatillas, Hombre  url: https://t.co/m-1n7Y6oH_l8JCQqaWpJaA  #valencia #vigo #bilbao', ' url: https://t.co/9rJOUrrFjs56EKUC7Mx5sg  #1: K-Swiss Ultra-Express Omni N Zapatillas, Hombre  url: https://t.co/THBZOc7v4Nk4oN17r-3R4A  #valencia #vigo #bilbao', ' url: https://t.co/9rJOUrrFjs56EKUC7Mx5sg  |MÃ¡s vendido #9: Columbia Redmond Leather Omni-Tech, Zapatos deâ\x80¦  url: https://t.co/CooLh5y-ylT5yRPoPcNcJQ  #valencia #vigo #bilbao', ' url: https://t.co/9rJOUrrFjs56EKU ...
# 041i2n8hCa9wjUFHTvbucw ['I just checked in at Omni Hotels &amp; Resorts with #mPLUSPlaces Download today!   url: https://t.co/9vAvYhZPP1LylDpxkmaVMQ ', 'I just checked in at Omni Hotels &amp; Resorts with #mPLUSPlaces Download today!   url: https://t.co/9vAvYhZPP1LylDpxkmaVMQ ']
# GpiuNvbRtbXwfynWiD_czA ["RT @un: ni5gBb-Wd09AATHp_0BNWQ : Vados argues that they all owe Goku their lives. Without his tournament idea, Omni-King would've just destroyed their universeâ\x80¦"]
# N1t6Jzysm3Y885HGvTXLkQ ["RT @un: ni5gBb-Wd09AATHp_0BNWQ : Vados argues that they all owe Goku their lives. Without his tournament idea, Omni-King would've just destroyed their universeâ\x80¦"]
# J7cIIyhO_8L3P1V_U-HlLw ['Melanin ð\x9f\x92¥ @ Omni Parker House  url: https://t.co/yl_Uuckb1A_OOaoQgXriaw ']
# nLUp9Cli7fPuBSO8ghqgtQ ['RT @un: mVxBviHtNJhYzwLtlnrDKQ : Check out Crochet World Omni Book Spring 1983 #CrochetWorld  url: https://t.co/J4E10ehUn1dIXykFNsOE-Q  via @un: KCU5mHoidt1SWfjnRdZooQ ', 'RT @un: DPPto4ZITAWw8FDTCFi8vg : The OMNI offers all carrying positions with no insert for infants required! Who could ask for more? #InMyErgo? AD']

# %%
user_to_tweets = f"{outdir}/table.by.user.pkl"

# %% [markdown]
# ## 2. Get the post texts of users from the coordinated connected component

# %%
# get the tweet texts for each connected component for manual annotation
has_text = twttext is not None
if has_text:
    with open(twttext, "rb") as f:
        tweet_table = pickle.load(f)
# texts (list of dict): each element is a connected component
# represented by a dictionary where each key is a node_id and the value is the tweet text
texts = [
    {node_id: tweet_table[node_id] for node_id in component}
    for component in nx.connected_components(G)
]
texts.sort(key=len, reverse=True)
# save to file
with open(grouptext, "wb") as f:
    pickle.dump(texts, f)

# %%
texts
# Out:
# [{'OIOkXKf3p-rjjf5hMlyp6Q': ['RT @un: FV7wzePr5Cz_5f4gEjkZQw : @un: uZJAmvOkoJiV_zazPeCXDA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: k1W8MRWz05RszT537A8rMQ â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: gxZkAmskUwpCjznO-dr9Bw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial: @un: YBJ7yw8J1qsl0VwHrbNIbg  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: uZJAmvOkoJiV_zazPeCXDA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw â\x80¦ ',
#    'RT @un: wmly5A_oy7R3tQm_8xRfkA _PASION__: @un: YBJ7yw8J1qsl0VwHrbNIbg  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: uZJAmvOkoJiV_zazPeCXDA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: FV7wzePr5Cz_5f4gEjkZQw â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: hAbk8HqzJd1e6_RJtP5_eg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: FV7wzePr5Cz_5f4gEjkZQw : @un: TKw_MHQiJXPco7E_XOuibg  @un: SGMa5xvrMyXaVnpjPKj0LA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: uZJAmvOkoJiV_zazPeCXDA  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: hAbk8HqzJd1e6_RJtP5_eg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ '],
#   'jxjOj0Ve9nGbRqnFaA6hqg': ['RT @un: FV7wzePr5Cz_5f4gEjkZQw : @un: SGMa5xvrMyXaVnpjPKj0LA  @un: uZJAmvOkoJiV_zazPeCXDA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: uZJAmvOkoJiV_zazPeCXDA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: uZJAmvOkoJiV_zazPeCXDA : @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: SGMa5xvrMyXaVnpjPKj0LA  @un: FV7wzePr5Cz_5f4gEjkZQw  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: k1W8MRWz05RszT537A8rMQ â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: uZJAmvOkoJiV_zazPeCXDA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: k1W8MRWz05RszT537A8rMQ â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: ClP3YQ-J4rBZNbyJIY915g  @un: gxZkAmskUwpCjznO-dr9Bw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: 24Igax1JBC0acQ6ciMIdNg _fynnyâ\x80¦ ',
#    'RT @un: wmly5A_oy7R3tQm_8xRfkA _PASION__: @un: YBJ7yw8J1qsl0VwHrbNIbg  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: uZJAmvOkoJiV_zazPeCXDA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: FV7wzePr5Cz_5f4gEjkZQw â\x80¦ ',
#    'RT @un: gxZkAmskUwpCjznO-dr9Bw : @un: SGMa5xvrMyXaVnpjPKj0LA  @un: ClP3YQ-J4rBZNbyJIY915g  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: 24Igax1JBC0acQ6ciMIdNg _fynnyâ\x80¦ ',
#    'RT @un: hAbk8HqzJd1e6_RJtP5_eg : @un: uZJAmvOkoJiV_zazPeCXDA  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: k1W8MRWz05RszT537A8rMQ : @un: DMhqX8FOmoJwdO5ibABtqQ  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: hAbk8HqzJd1e6_RJtP5_eg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: SGMa5xvrMyXaVnpjPKj0LA  @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: TKw_MHQiJXPco7E_XOuibg : @un: SGMa5xvrMyXaVnpjPKj0LA  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: oINsZZZDUQDZe_6ZK0KfuQ  @un: ClP3YQ-J4rBZNbyJIY915g  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: k1W8MRWz05RszT537A8rMQ â\x80¦ ',
#    'RT @un: 0k_cUCmSUKXltfnu8yq4Yw : @un: hAbk8HqzJd1e6_RJtP5_eg  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: okS8K-QkXAInSCNaRt7fFQ _Haif @un: SGMa5xvrMyXaVnpjPKj0LA  @un: FV7wzePr5Cz_5f4gEjkZQw  @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA â\x80¦ ',
#    'RT @un: hAbk8HqzJd1e6_RJtP5_eg : @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: okS8K-QkXAInSCNaRt7fFQ _Haif @un: SGMa5xvrMyXaVnpjPKj0LA  @un: FV7wzePr5Cz_5f4gEjkZQw  @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: FV7wzePr5Cz_5f4gEjkZQw  @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: FV7wzePr5Cz_5f4gEjkZQw  @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: 0k_cUCmSUKXltfnu8yq4Yw : @un: SGMa5xvrMyXaVnpjPKj0LA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: hAbk8HqzJd1e6_RJtP5_eg  @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: FV7wzePr5Cz_5f4gEjkZQw  @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: FV7wzePr5Cz_5f4gEjkZQw : @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: SGMa5xvrMyXaVnpjPKj0LA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: hAbk8HqzJd1e6_RJtP5_eg : @un: mAaLco-ytreg2h8pJr7IbQ _22 @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: okS8K-QkXAInSCNaRt7fFQ _Haif @un: SGMa5xvrMyXaVnpjPKj0LA  @un: FV7wzePr5Cz_5f4gEjkZQw  @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: hAbk8HqzJd1e6_RJtP5_eg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: L-nbZF_-nQTS4FZTgLDhtw : @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: L-nbZF_-nQTS4FZTgLDhtw  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ '],
#   'xTKaJEc7Z3j5rCOalr_3Dw': ['RT @un: uZJAmvOkoJiV_zazPeCXDA : @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: uZJAmvOkoJiV_zazPeCXDA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: k1W8MRWz05RszT537A8rMQ â\x80¦ ',
#    'RT @un: wmly5A_oy7R3tQm_8xRfkA _PASION__: @un: SGMa5xvrMyXaVnpjPKj0LA  @un: FV7wzePr5Cz_5f4gEjkZQw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: k1W8MRWz05RszT537A8rMQ â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: gxZkAmskUwpCjznO-dr9Bw  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial: @un: YBJ7yw8J1qsl0VwHrbNIbg  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: uZJAmvOkoJiV_zazPeCXDA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: hAbk8HqzJd1e6_RJtP5_eg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: gxZkAmskUwpCjznO-dr9Bw : @un: SGMa5xvrMyXaVnpjPKj0LA  @un: ClP3YQ-J4rBZNbyJIY915g  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: 24Igax1JBC0acQ6ciMIdNg _fynnyâ\x80¦ ',
#    'RT @un: k1W8MRWz05RszT537A8rMQ : @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: FV7wzePr5Cz_5f4gEjkZQw : @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: SGMa5xvrMyXaVnpjPKj0LA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: uZJAmvOkoJiV_zazPeCXDA : @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: YBJ7yw8J1qsl0VwHrbNIbg  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: FV7wzePr5Cz_5f4gEjkZQw â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: uZJAmvOkoJiV_zazPeCXDA  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ '],
#   'sJClIs7khY43E8j6GSfSLA': ['RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: uZJAmvOkoJiV_zazPeCXDA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: 0k_cUCmSUKXltfnu8yq4Yw : @un: gxZkAmskUwpCjznO-dr9Bw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: SGMa5xvrMyXaVnpjPKj0LA  @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: gxZkAmskUwpCjznO-dr9Bw : @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: gxZkAmskUwpCjznO-dr9Bw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: hAbk8HqzJd1e6_RJtP5_eg : @un: uZJAmvOkoJiV_zazPeCXDA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial: @un: YBJ7yw8J1qsl0VwHrbNIbg  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: uZJAmvOkoJiV_zazPeCXDA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw â\x80¦ ',
#    'RT @un: TKw_MHQiJXPco7E_XOuibg : @un: SGMa5xvrMyXaVnpjPKj0LA  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: oINsZZZDUQDZe_6ZK0KfuQ  @un: ClP3YQ-J4rBZNbyJIY915g  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: k1W8MRWz05RszT537A8rMQ â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: FV7wzePr5Cz_5f4gEjkZQw  @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: FV7wzePr5Cz_5f4gEjkZQw : @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: SGMa5xvrMyXaVnpjPKj0LA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: okS8K-QkXAInSCNaRt7fFQ _Haif: @un: SGMa5xvrMyXaVnpjPKj0LA  @un: FV7wzePr5Cz_5f4gEjkZQw  @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__â\x80¦ '],
#   'IB4Z_5Jr2a6__S1TEbbJWQ': ['RT @un: FV7wzePr5Cz_5f4gEjkZQw : @un: SGMa5xvrMyXaVnpjPKj0LA  @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: wmly5A_oy7R3tQm_8xRfkA _PASION__: @un: SGMa5xvrMyXaVnpjPKj0LA  @un: FV7wzePr5Cz_5f4gEjkZQw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: k1W8MRWz05RszT537A8rMQ â\x80¦ ',
#    'RT @un: gxZkAmskUwpCjznO-dr9Bw : @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: hAbk8HqzJd1e6_RJtP5_eg : @un: FV7wzePr5Cz_5f4gEjkZQw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: 0k_cUCmSUKXltfnu8yq4Yw : @un: ClP3YQ-J4rBZNbyJIY915g  @un: gxZkAmskUwpCjznO-dr9Bw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: SGMa5xvrMyXaVnpjPKj0LA  @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: 24Igax1JBC0acQ6ciMIdNg _fynnyâ\x80¦ ',
#    'RT @un: 0k_cUCmSUKXltfnu8yq4Yw : @un: gxZkAmskUwpCjznO-dr9Bw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: SGMa5xvrMyXaVnpjPKj0LA  @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: gxZkAmskUwpCjznO-dr9Bw  @un: ClP3YQ-J4rBZNbyJIY915g  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: 24Igax1JBC0acQ6ciMIdNg _fynnyâ\x80¦ ',
#    'RT @un: FV7wzePr5Cz_5f4gEjkZQw : @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: SGMa5xvrMyXaVnpjPKj0LA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: TKw_MHQiJXPco7E_XOuibg : @un: FV7wzePr5Cz_5f4gEjkZQw  @un: SGMa5xvrMyXaVnpjPKj0LA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: FV7wzePr5Cz_5f4gEjkZQw : @un: TKw_MHQiJXPco7E_XOuibg  @un: SGMa5xvrMyXaVnpjPKj0LA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: k1W8MRWz05RszT537A8rMQ : @un: SGMa5xvrMyXaVnpjPKj0LA  @un: uZJAmvOkoJiV_zazPeCXDA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: k1W8MRWz05RszT537A8rMQ : @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: FV7wzePr5Cz_5f4gEjkZQw  @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: uZJAmvOkoJiV_zazPeCXDA : @un: L-nbZF_-nQTS4FZTgLDhtw  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ '],
#   'owJUtYIQOVNeo4CmzdEBqw': ['RT @un: uZJAmvOkoJiV_zazPeCXDA : @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: uZJAmvOkoJiV_zazPeCXDA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: gxZkAmskUwpCjznO-dr9Bw  @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: hAbk8HqzJd1e6_RJtP5_eg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: gxZkAmskUwpCjznO-dr9Bw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: gxZkAmskUwpCjznO-dr9Bw  @un: ClP3YQ-J4rBZNbyJIY915g  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: 24Igax1JBC0acQ6ciMIdNg _fynnyâ\x80¦ ',
#    'RT @un: hAbk8HqzJd1e6_RJtP5_eg : @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: SGMa5xvrMyXaVnpjPKj0LA  @un: FV7wzePr5Cz_5f4gEjkZQw  @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: FV7wzePr5Cz_5f4gEjkZQw  @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: TKw_MHQiJXPco7E_XOuibg : @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: SGMa5xvrMyXaVnpjPKj0LA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: oINsZZZDUQDZe_6ZK0KfuQ  @un: ClP3YQ-J4rBZNbyJIY915g  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: k1W8MRWz05RszT537A8rMQ â\x80¦ ',
#    'RT @un: uZJAmvOkoJiV_zazPeCXDA : @un: L-nbZF_-nQTS4FZTgLDhtw  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: k1W8MRWz05RszT537A8rMQ : @un: SGMa5xvrMyXaVnpjPKj0LA  @un: uZJAmvOkoJiV_zazPeCXDA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: k1W8MRWz05RszT537A8rMQ  @un: uZJAmvOkoJiV_zazPeCXDA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw â\x80¦ ',
#    'RT @un: FV7wzePr5Cz_5f4gEjkZQw : @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: SGMa5xvrMyXaVnpjPKj0LA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: hAbk8HqzJd1e6_RJtP5_eg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: L-nbZF_-nQTS4FZTgLDhtw : @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ â\x80¦ '],
#   'dP9k3ng1n6UGxhRp9QgcxA': ['RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: uZJAmvOkoJiV_zazPeCXDA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: k1W8MRWz05RszT537A8rMQ â\x80¦ ',
#    'RT @un: FV7wzePr5Cz_5f4gEjkZQw : @un: SGMa5xvrMyXaVnpjPKj0LA  @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: wmly5A_oy7R3tQm_8xRfkA _PASION__: @un: SGMa5xvrMyXaVnpjPKj0LA  @un: FV7wzePr5Cz_5f4gEjkZQw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: k1W8MRWz05RszT537A8rMQ â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: k1W8MRWz05RszT537A8rMQ â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: gxZkAmskUwpCjznO-dr9Bw  @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: 0k_cUCmSUKXltfnu8yq4Yw : @un: gxZkAmskUwpCjznO-dr9Bw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: SGMa5xvrMyXaVnpjPKj0LA  @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: hAbk8HqzJd1e6_RJtP5_eg : @un: uZJAmvOkoJiV_zazPeCXDA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: hAbk8HqzJd1e6_RJtP5_eg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: k1W8MRWz05RszT537A8rMQ : @un: DMhqX8FOmoJwdO5ibABtqQ  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: hAbk8HqzJd1e6_RJtP5_eg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: SGMa5xvrMyXaVnpjPKj0LA  @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: hAbk8HqzJd1e6_RJtP5_eg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: 24Igax1JBC0acQ6ciMIdNg _fynny: @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: hAbk8HqzJd1e6_RJtP5_eg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: SGMa5xvrMyXaVnpjPKj0LA  @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: hAbk8HqzJd1e6_RJtP5_eg : @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: okS8K-QkXAInSCNaRt7fFQ _Haif @un: SGMa5xvrMyXaVnpjPKj0LA  @un: FV7wzePr5Cz_5f4gEjkZQw  @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: TKw_MHQiJXPco7E_XOuibg : @un: SGMa5xvrMyXaVnpjPKj0LA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: TKw_MHQiJXPco7E_XOuibg : @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: SGMa5xvrMyXaVnpjPKj0LA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: oINsZZZDUQDZe_6ZK0KfuQ  @un: ClP3YQ-J4rBZNbyJIY915g  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: k1W8MRWz05RszT537A8rMQ â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: uZJAmvOkoJiV_zazPeCXDA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: YBJ7yw8J1qsl0VwHrbNIbg  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: FV7wzePr5Cz_5f4gEjkZQw â\x80¦ ',
#    'RT @un: FV7wzePr5Cz_5f4gEjkZQw : @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: SGMa5xvrMyXaVnpjPKj0LA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: FV7wzePr5Cz_5f4gEjkZQw  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: k1W8MRWz05RszT537A8rMQ â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: uZJAmvOkoJiV_zazPeCXDA  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ '],
#   '8smFZJ844Lw9dZZDkN9nHQ': ['RT @un: FV7wzePr5Cz_5f4gEjkZQw : @un: uZJAmvOkoJiV_zazPeCXDA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: wmly5A_oy7R3tQm_8xRfkA _PASION__: @un: SGMa5xvrMyXaVnpjPKj0LA  @un: FV7wzePr5Cz_5f4gEjkZQw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: k1W8MRWz05RszT537A8rMQ â\x80¦ ',
#    'RT @un: 0k_cUCmSUKXltfnu8yq4Yw : @un: gxZkAmskUwpCjznO-dr9Bw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: SGMa5xvrMyXaVnpjPKj0LA  @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: gxZkAmskUwpCjznO-dr9Bw : @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: hAbk8HqzJd1e6_RJtP5_eg : @un: uZJAmvOkoJiV_zazPeCXDA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: wmly5A_oy7R3tQm_8xRfkA _PASION__: @un: YBJ7yw8J1qsl0VwHrbNIbg  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: uZJAmvOkoJiV_zazPeCXDA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: FV7wzePr5Cz_5f4gEjkZQw â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: hAbk8HqzJd1e6_RJtP5_eg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: hAbk8HqzJd1e6_RJtP5_eg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: gxZkAmskUwpCjznO-dr9Bw : @un: x1qwWobBWUNkAB4zx4VD4Q  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: SGMa5xvrMyXaVnpjPKj0LA  @un: uZJAmvOkoJiV_zazPeCXDA â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: hAbk8HqzJd1e6_RJtP5_eg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: FV7wzePr5Cz_5f4gEjkZQw  @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: TKw_MHQiJXPco7E_XOuibg : @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: SGMa5xvrMyXaVnpjPKj0LA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: oINsZZZDUQDZe_6ZK0KfuQ  @un: ClP3YQ-J4rBZNbyJIY915g  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: k1W8MRWz05RszT537A8rMQ â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: hAbk8HqzJd1e6_RJtP5_eg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: FV7wzePr5Cz_5f4gEjkZQw  @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: TKw_MHQiJXPco7E_XOuibg : @un: FV7wzePr5Cz_5f4gEjkZQw  @un: SGMa5xvrMyXaVnpjPKj0LA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: FV7wzePr5Cz_5f4gEjkZQw  @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: k1W8MRWz05RszT537A8rMQ : @un: uZJAmvOkoJiV_zazPeCXDA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: k1W8MRWz05RszT537A8rMQ : @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: FV7wzePr5Cz_5f4gEjkZQw  @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: uZJAmvOkoJiV_zazPeCXDA : @un: L-nbZF_-nQTS4FZTgLDhtw  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: uZJAmvOkoJiV_zazPeCXDA  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ '],
#   'dby7MxG78gnrl7F-cEEA9w': ['RT @un: FV7wzePr5Cz_5f4gEjkZQw : @un: SGMa5xvrMyXaVnpjPKj0LA  @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: gxZkAmskUwpCjznO-dr9Bw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: 0k_cUCmSUKXltfnu8yq4Yw : @un: hAbk8HqzJd1e6_RJtP5_eg  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: okS8K-QkXAInSCNaRt7fFQ _Haif @un: SGMa5xvrMyXaVnpjPKj0LA  @un: FV7wzePr5Cz_5f4gEjkZQw  @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA â\x80¦ ',
#    'RT @un: TKw_MHQiJXPco7E_XOuibg : @un: SGMa5xvrMyXaVnpjPKj0LA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: FV7wzePr5Cz_5f4gEjkZQw  @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: TKw_MHQiJXPco7E_XOuibg  @un: FV7wzePr5Cz_5f4gEjkZQw  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: uZJAmvOkoJiV_zazPeCXDA : @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: YBJ7yw8J1qsl0VwHrbNIbg  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: FV7wzePr5Cz_5f4gEjkZQw â\x80¦ ',
#    'RT @un: hAbk8HqzJd1e6_RJtP5_eg : @un: mAaLco-ytreg2h8pJr7IbQ _22 @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: okS8K-QkXAInSCNaRt7fFQ _Haif @un: SGMa5xvrMyXaVnpjPKj0LA  @un: FV7wzePr5Cz_5f4gEjkZQw  @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA â\x80¦ '],
#   'WQcXPgiES4M3hzKdRqRMfA': ['RT @un: FV7wzePr5Cz_5f4gEjkZQw : @un: SGMa5xvrMyXaVnpjPKj0LA  @un: uZJAmvOkoJiV_zazPeCXDA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: hAbk8HqzJd1e6_RJtP5_eg : @un: d0q6hpj7yeac50AxnpTfkg _ @un: YBJ7yw8J1qsl0VwHrbNIbg  @un: k1W8MRWz05RszT537A8rMQ  @un: SGMa5xvrMyXaVnpjPKj0LA  @un: uZJAmvOkoJiV_zazPeCXDA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficialâ\x80¦ ',
#    'RT @un: FV7wzePr5Cz_5f4gEjkZQw : @un: SGMa5xvrMyXaVnpjPKj0LA  @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: gxZkAmskUwpCjznO-dr9Bw  @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: 0k_cUCmSUKXltfnu8yq4Yw : @un: gxZkAmskUwpCjznO-dr9Bw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: SGMa5xvrMyXaVnpjPKj0LA  @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: 0k_cUCmSUKXltfnu8yq4Yw : @un: ClP3YQ-J4rBZNbyJIY915g  @un: gxZkAmskUwpCjznO-dr9Bw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: SGMa5xvrMyXaVnpjPKj0LA  @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: 24Igax1JBC0acQ6ciMIdNg _fynnyâ\x80¦ ',
#    'RT @un: wmly5A_oy7R3tQm_8xRfkA _PASION__: @un: YBJ7yw8J1qsl0VwHrbNIbg  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: uZJAmvOkoJiV_zazPeCXDA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: FV7wzePr5Cz_5f4gEjkZQw â\x80¦ ',
#    'RT @un: hAbk8HqzJd1e6_RJtP5_eg : @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: SGMa5xvrMyXaVnpjPKj0LA  @un: FV7wzePr5Cz_5f4gEjkZQw  @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ â\x80¦ ',
#    'RT @un: TKw_MHQiJXPco7E_XOuibg : @un: SGMa5xvrMyXaVnpjPKj0LA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: TKw_MHQiJXPco7E_XOuibg : @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: SGMa5xvrMyXaVnpjPKj0LA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: oINsZZZDUQDZe_6ZK0KfuQ  @un: ClP3YQ-J4rBZNbyJIY915g  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: k1W8MRWz05RszT537A8rMQ â\x80¦ ',
#    'RT @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial: @un: FA0gXVRMzpwGVBobnk6P2w  @un: SGMa5xvrMyXaVnpjPKj0LA  @un: k1W8MRWz05RszT537A8rMQ  @un: uZJAmvOkoJiV_zazPeCXDA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw â\x80¦ ',
#    'RT @un: TKw_MHQiJXPco7E_XOuibg : @un: FV7wzePr5Cz_5f4gEjkZQw  @un: SGMa5xvrMyXaVnpjPKj0LA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: 0k_cUCmSUKXltfnu8yq4Yw : @un: SGMa5xvrMyXaVnpjPKj0LA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: hAbk8HqzJd1e6_RJtP5_eg  @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: hAbk8HqzJd1e6_RJtP5_eg : @un: mAaLco-ytreg2h8pJr7IbQ _22 @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: okS8K-QkXAInSCNaRt7fFQ _Haif @un: SGMa5xvrMyXaVnpjPKj0LA  @un: FV7wzePr5Cz_5f4gEjkZQw  @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: uZJAmvOkoJiV_zazPeCXDA  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: L-nbZF_-nQTS4FZTgLDhtw : @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: L-nbZF_-nQTS4FZTgLDhtw  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: okS8K-QkXAInSCNaRt7fFQ _Haif: @un: SGMa5xvrMyXaVnpjPKj0LA  @un: FV7wzePr5Cz_5f4gEjkZQw  @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__â\x80¦ '],
#   'zUd8AT9qYpxs62mDJdd5Gw': ['RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: k1W8MRWz05RszT537A8rMQ â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: gxZkAmskUwpCjznO-dr9Bw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: gxZkAmskUwpCjznO-dr9Bw : @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw â\x80¦ ',
#    'RT @un: gxZkAmskUwpCjznO-dr9Bw : @un: SGMa5xvrMyXaVnpjPKj0LA  @un: ClP3YQ-J4rBZNbyJIY915g  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: 24Igax1JBC0acQ6ciMIdNg _fynnyâ\x80¦ ',
#    'RT @un: hAbk8HqzJd1e6_RJtP5_eg : @un: uZJAmvOkoJiV_zazPeCXDA  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: 24Igax1JBC0acQ6ciMIdNg _fynny: @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: hAbk8HqzJd1e6_RJtP5_eg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: SGMa5xvrMyXaVnpjPKj0LA  @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: uZJAmvOkoJiV_zazPeCXDA : @un: L-nbZF_-nQTS4FZTgLDhtw  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: FV7wzePr5Cz_5f4gEjkZQw : @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: SGMa5xvrMyXaVnpjPKj0LA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: FV7wzePr5Cz_5f4gEjkZQw  @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 0k_cUCmSUKXltfnu8yq4Yw â\x80¦ ',
#    'RT @un: uZJAmvOkoJiV_zazPeCXDA : @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: YBJ7yw8J1qsl0VwHrbNIbg  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: hAbk8HqzJd1e6_RJtP5_eg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: FV7wzePr5Cz_5f4gEjkZQw â\x80¦ ',
#    'RT @un: k1W8MRWz05RszT537A8rMQ : @un: uZJAmvOkoJiV_zazPeCXDA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: hAbk8HqzJd1e6_RJtP5_eg : @un: mAaLco-ytreg2h8pJr7IbQ _22 @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: okS8K-QkXAInSCNaRt7fFQ _Haif @un: SGMa5xvrMyXaVnpjPKj0LA  @un: FV7wzePr5Cz_5f4gEjkZQw  @un: TKw_MHQiJXPco7E_XOuibg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: uZJAmvOkoJiV_zazPeCXDA â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: 24Igax1JBC0acQ6ciMIdNg _fynny @un: k1W8MRWz05RszT537A8rMQ  @un: DMhqX8FOmoJwdO5ibABtqQ  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: hAbk8HqzJd1e6_RJtP5_eg  @un: gxZkAmskUwpCjznO-dr9Bw  @un: FA0gXVRMzpwGVBobnk6P2w â\x80¦ ',
#    'RT @un: L-nbZF_-nQTS4FZTgLDhtw : @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ â\x80¦ ',
#    'RT @un: SGMa5xvrMyXaVnpjPKj0LA : @un: L-nbZF_-nQTS4FZTgLDhtw  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ '],
#   'UR1b4CKvXix8F345Pu4APg': ['RT @un: FV7wzePr5Cz_5f4gEjkZQw : @un: uZJAmvOkoJiV_zazPeCXDA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: SGMa5xvrMyXaVnpjPKj0LA  @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: 2p1u-4o4V6LlUs2QlgWYmg â\x80¦ ',
#    'RT @un: k1W8MRWz05RszT537A8rMQ : @un: hAbk8HqzJd1e6_RJtP5_eg  @un: SGMa5xvrMyXaVnpjPKj0LA  @un: uZJAmvOkoJiV_zazPeCXDA  @un: gxZkAmskUwpCjznO-dr9Bw  @un: L-nbZF_-nQTS4FZTgLDhtw  @un: 6fxlMQWzQ0oRwDQ41Wp2tg _Oficial @un: wmly5A_oy7R3tQm_8xRfkA _PASION__ @un: FV7wzePr5Cz_5f4gEjkZQw â\x80¦ ',
#    'RT @un: wmly5A_oy7R3tQm_8xRfkA _PASION__: @un: SGMa5xvrMyXaVnpjPKj0LA  @un: FV7wzePr5Cz_5f4gEjkZQw  @un: uZJAmvOkoJiV_zazPeCXDA  @un: 2p1u-4o4V6LlUs2QlgWYmg  @un: 8edZUNkogcbvwltdGLvSjQ  @un: gxZkAmskUwpCjznO-dr9Bw  @un: 0k_cUCmSUKXltfnu8yq4Yw  @un: k1W8MRWz05RszT537A8rMQ â\x80¦ ',
# ...
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : "Blockchain â\x80\x93 Enabling The True Peer To Peer Economy" via @un: 4WDlV2PHnghJZqG3FgsmDg  by Indorse CEO @un: FyUi7BAoq3gdnf0X6spEJw _mosk \\n\\n url: https://t.co/0gX6dtMKdwCmK871IXlpbA ']},
#  {'qtMHBtq6SBG0d2Tc5gKmZA': ['Retweeted Indorse (@un: jiCrvwK2UQPTuWK2k73zLg ):\\n\\nAnnouncing IND Airdrop: PAY, DGD, CDT, ZRX holders to be airdropped...  url: https://t.co/xJZPIDEwY7kYbqYJAEpQRA ',
#    'Retweeted Indorse (@un: jiCrvwK2UQPTuWK2k73zLg ):\\n\\nIndorse Utilizes Ethereum to Improve Social Networks and Online Reputation via...  url: https://t.co/-bfG6UMgnl-JPUf5f_lwjw ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : "How Blockchain Will Shape the Future of Social Networks" by Indorse CTO @un: yuMzDTFTid0ctUJkPeA-tw  in @un: i4Iw8QQdUd_bfVmGkjBkHA  ð\x9f\x91\x8d\\n\\n url: https://t.co/jpfd9yOsY_bYG7iZCdjVBw â\x80¦',
#    'Retweeted Indorse (@un: jiCrvwK2UQPTuWK2k73zLg ):\\n\\nWeâ\x80\x99ve received 20,270 ETH so far &amp; reached 40.5% of the hard cap. ð\x9f\x99\x8c...  url: https://t.co/7CtkOHiMcUH-2Nb5ZiPN4g ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Ethereum Based Startup â\x80\x9cIndorseâ\x80\x9d Seeks to Disrupt Reputation and Personal Branding Online via @un: cVY7KdBBAUbvA0v13t1bJQ  \\n\\n url: https://t.c â\x80¦',
#    'RT @un: _c883ATzZyV8kjguAytikw _Token: STORM Token Partners with @un: c6X2sn6qieEyDldSF5tqcA ! Read more:  url: https://t.co/1iWz5ZPeO8AoizfGQ9CYHA ',
#    'Retweeted Indorse (@un: jiCrvwK2UQPTuWK2k73zLg ):\\n\\nIndorse Airdrop FAQs - Answered!\\n\\n url: https://t.co/BdzggSJKRq3m5eFKb_OF7A   url: https://t.co/uE5EYlcyoPqZGJFB0ThwyA ',
#    'Retweeted Indorse (@un: jiCrvwK2UQPTuWK2k73zLg ):\\n\\nIndorse Latest Dev Update: \\n\\n- Scaling up of staff\\n- KyberNetwork Airdrop\\n-...  url: https://t.co/Z0_nNxV7svUvOV7JTwBhJg ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Announcing community migration to Rocket Chat along with @un: ZJmlbc20vPTDpJggLggQqg , @un: X4WsrSMX9kr1PxavTCl2ng , @un: h5HioEXa2zOtA2iZlAn27w _go, @un: 73MvZ-RS-smP7gXK799rQg  \\n\\n https:/â\x80¦',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Indorse INDâ\x80\x8aâ\x80\x94â\x80\x8aBNT Token Changer for @un: c6X2sn6qieEyDldSF5tqcA   \\n\\n url: https://t.co/v-ybQ0WoCKvsLIXL64HqjQ ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Nice overview of Indorse -- "BUSINESS SHOWCASE : INDORSE" by @un: bFNWQOXv-AYKFvQSEc-Jow  via @un: LPznlvRwPVYK4cOhs_t-dA _TechNews \\n\\n url: https://t.co/FdWqNck8JK1x7RRZZ-NcFQ ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Indorse presentation at Block One in Melbourne by @un: FyUi7BAoq3gdnf0X6spEJw _mosk \\n url: https://t.co/sNSaztt8YHD1F1KEEumMZg ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Indorse Advisor, and @un: F3uYfzUya1aXNMvnUe7vdg  CEO (our lead investor) @un: buFPd5RVdvAYHhLkbfxNKg  rocking the stage at Startup Token in Buâ\x80¦ ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Blockchain professional social network Indorse raises $9M in token sale\\n\\n url: https://t.co/xrtXg3ACPrHy19q4qL6vVA ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Indorse Dev Updateâ\x80\x8aâ\x80\x94â\x80\x8a15 September 2017 -- Changing the world one skill at a time! ð\x9f\x9b\xa0ï¸\x8f\\n\\n url: https://t.co/6Mtq3o8uWGmiucMRG-OHcw ',
#    'Retweeted Indorse (@un: jiCrvwK2UQPTuWK2k73zLg ):\\n\\nAnd millenials will soon be able to earn cryptocurrencies on platforms like...  url: https://t.co/u83uhdEcVk1zYtPCpzHEfA ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : If data is new oil, are tech companies robbing us blind? \\n@un: kF7B7V6xggC-Y_51mkYIiw  Yes, and Indorse is solving this problem!\\n url: https://t â\x80¦',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : "How Singapore became a hot ICO destination" in @un: wpipFxSA4WETiPYqCaWrhw  by Indorse CEO @un: FyUi7BAoq3gdnf0X6spEJw _mosk \\n\\n url: https://t.co/8f7TMT-NkuFtJsaHE-5hMg ',
#    'Retweeted Indorse (@un: jiCrvwK2UQPTuWK2k73zLg ):\\n\\nPlease take this short survey to help us understand and create a report on how...  url: https://t.co/JzuMHXh61B7FLMLoAuE7Yg ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Please take this short survey to help us understand and create a report on how people use endorsements currently!  \\n https:â\x80¦',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Indorse token sale is closed! Thank you everyone for your support and trust!\\n\\nTokens will be transferable after 14 Septembâ\x80¦',
#    'Retweeted Indorse (@un: jiCrvwK2UQPTuWK2k73zLg ):\\n\\nIndorse token sale is closed! Thank you everyone for your support and trust!...  url: https://t.co/T5RZwcpk2etyvrpBvjSnsA ',
#    'Retweeted Indorse (@un: jiCrvwK2UQPTuWK2k73zLg ):\\n\\nRead more about our advisor and @un: 6gfF2pZFBIJpPvZWK_x9bg  CEO @un: hKs2splbs5Sds0A4orJMZA _luu...  url: https://t.co/Ddsj-gfsqXoolQsURfk2Iw '],
#   'brH5JNzSbHg4wdp-Unw30w': ['RT @un: jiCrvwK2UQPTuWK2k73zLg : Indorse Public Token Sale Launch &amp; Grant of Option\\n\\n url: https://t.co/n2_8V4znrbYgZAv-mN1JOQ ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Ethereum Based Startup â\x80\x9cIndorseâ\x80\x9d Seeks to Disrupt Reputation and Personal Branding Online via @un: cVY7KdBBAUbvA0v13t1bJQ  \\n\\n url: https://t.c â\x80¦',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Weâ\x80\x99ve received 20,270 ETH so far &amp; reached 40.5% of the hard cap. ð\x9f\x99\x8c\\n\\nParticipate in the Token Sale:  url: https://t.co/dg6vCnI0PhPALlyQZzj84w ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : How Ethereum Blockchain Can Solve Your Social Media Privacy Problem via @un: q823ilZOAKvLge6VPyLPBA  \\n\\n url: https://t.co/5ruGoZs84jCwCZwBh7lvlw ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Announcing community migration to Rocket Chat along with @un: ZJmlbc20vPTDpJggLggQqg , @un: X4WsrSMX9kr1PxavTCl2ng , @un: h5HioEXa2zOtA2iZlAn27w _go, @un: 73MvZ-RS-smP7gXK799rQg  \\n\\n https:/â\x80¦',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Indorse Advisor, and @un: F3uYfzUya1aXNMvnUe7vdg  CEO (our lead investor) @un: buFPd5RVdvAYHhLkbfxNKg  rocking the stage at Startup Token in Buâ\x80¦ ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Blockchain professional social network Indorse raises $9M in token sale\\n\\n url: https://t.co/xrtXg3ACPrHy19q4qL6vVA ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Indorse CTO @un: yuMzDTFTid0ctUJkPeA-tw  presenting Indorse at #Worldblockchainforum Keynote Conference London!  url: https://t.co/haS_A-pyyuZlfuAE0xb-QA ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Indorse token sale is closed! Thank you everyone for your support and trust!\\n\\nTokens will be transferable after 14 Septembâ\x80¦',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : "Singapore social network Indorse lets users control their data, raises US$9M" via @un: lEK31AnJnqQ1bswxQwH1eg  \\n\\n url: https://t.co/FDggj02sR_rRpT4nE32MNQ ']},
#  {'cBL0jaBxd3epaf7kv___eQ': ['RT @un: jiCrvwK2UQPTuWK2k73zLg : Want to know more about Indorse? Check out draft of the White Paper -  url: https://t.co/wq6MWJ6PUGEcZYdijQHa_Q  welcome and appreciate yâ\x80¦',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Important: All announcements - Bounty, Pre Token Sale, Token Sale, will be first made exclusively on Indorse Slack:  https:â\x80¦',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Learn more about  url: url: https://t .co/bFcN_LX5j1a9GtrRkNKoYA  with Project Head @un: FyUi7BAoq3gdnf0X6spEJw _mosk at #ETHEREUM Hong Kong meetup tomorrow!\\n\\n url: https://t .â\x80¦',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Indorse Tech Lead @un: yuMzDTFTid0ctUJkPeA-tw  presenting Indorse @un: MhQ_dV98_2vnP_fPxnw0FQ  #ethereum #blockchain  url: https://t.co/usPR3Me7Zftfw7cfxD2MXA ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Receive 25% bonus IND tokens in the Token Pre-Sale. Participate now:  url: https://t.co/QCBC3EKkI34n4Pgzx_GF5g   url: https://t.co/PeA3sM2RX70vHBW3feyLNg ',
#    "RT @un: jiCrvwK2UQPTuWK2k73zLg : Indorse Pre-Sale is over! Thank you for your trust &amp; support! ð\x9f\x99\x8c\\n\\nIgnore DMs stating it's open! We'll never post a contractâ\x80¦",
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Indorse Token Post Pre-Sale Analysis! Pre-Sale is closed &amp; Token Sale will open on Aug 8th! Be wary of scams!\\n\\n url: https://t.c â\x80¦',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Decentralized Professional Network Indorse Gives Users The Power Of Their Data Back via @un: Gw8aAzTi6eCKSdYvS3oo7Q  \\n url: https://t.co/m2iXauI_lnY9hH6zU_nByw â\x80¦',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Indorse IND tokens will be tradeable on @un: O-pbuegIGiElqUvSGBgbpw  once theyâ\x80\x99re transferable (7 days after the end of the token saâ\x80¦ ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Indorse Public Token Sale Launch &amp; Grant of Option\\n\\n url: https://t.co/n2_8V4znrbYgZAv-mN1JOQ ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : With 30,005.934 ETH received so far, weâ\x80\x99ve hit the 60% of the hard cap ð\x9f\x99\x8c\\n\\nParticipate now:  url: https://t.co/dg6vCnI0PhPALlyQZzj84w   https:/â\x80¦'],
#   'iaBR0MlZF9AXGWDg-lqixw': ['RT @un: jiCrvwK2UQPTuWK2k73zLg : Post your skills, get paid! New cryptocurrency based social network on #ethereum #blockchain\\nLearn more:â\x80¦ ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : .@un: yuMzDTFTid0ctUJkPeA-tw  will be speaking about indorse.io &amp; #Blockchain ecosystem in the SEA region  url: https://t.co/565CKNUpyTO8A_807YKkKw ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Indorse, a Decentralized Professional Network With Rewards, Powered by #ETHEREUM\\n url: https://t.co/LSjcPF8On0Mos2GCk62p0Q ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Indorse is now listed on @un: tAVV29OGUBbtP3tKm_O4Bg  ð\x9f\x99\x8c\\n\\n url: https://t.co/Rv6kbB3LgGG0QviihsuJqA ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Learn more about  url: url: https://t .co/bFcN_LX5j1a9GtrRkNKoYA  with Project Head @un: FyUi7BAoq3gdnf0X6spEJw _mosk at #ETHEREUM Hong Kong meetup tomorrow!\\n\\n url: https://t .â\x80¦',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Indorse, the Decentralized Professional Network on Ethereum, Joins Forces With @un: ZDJirvJ5j1ECOi7YQG_GjA  DAO\\n\\n url: https://t.co/83MFsBhkchF2jqffHZesdg ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Important: All announcements - Bounty, Token Pre-Sale, Token Sale, will be first made exclusively on Indorse Slack:  https:â\x80¦',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Decentralized Professional Network Indorse Will Reward You for Sharing Your Skills \\n url: https://t.co/FqJ3ffeskaoYv4gNnb9X1w ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : We welcome Patrick McCorry @un: RYWS7belRmZALp441lMzRg , Cryptocurrency Researcher @un: o2iS5myKJmr06yAuTk_KdQ  on Indorse Board of Advisors ð\x9f\x99\x8cð\x9f\x92ª  url: https://t.co/_2v8uXZfypQSyRqFbg9lEw â\x80¦',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Indorse advisor @un: hKs2splbs5Sds0A4orJMZA _luu will be presenting Kyber Network (decentralized asset exchange) this Friday in Singapore:  https:/â\x80¦',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Indorse - a Decentralized Professional Network. Thank you for the coverage @un: tAVV29OGUBbtP3tKm_O4Bg  \\n\\n url: https://t.co/nBUFe9TEcqkteezj0zCEMQ ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Excellent meetup at Beijing! Great questions &amp; interesting discussions about Indorse and its Token Sale happening oâ\x80¦ ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Indorse IND Token Sale starts on August 8th! 7 days to go!  url: https://t.co/r9CiEZCdHh8d_mVK3l6kAw ',
#    "RT @un: jiCrvwK2UQPTuWK2k73zLg : Indorse Presentation at #finwise! It's amazing to be a part of the Global Blockchain Summit by @un: 5o4_IMSujYZ8M98Jpt2HDw _orgâ\x80¦ ",
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Indorse Token Saleâ\x80\x8aâ\x80\x94â\x80\x8aEverything you should know about\\n\\n url: https://t.co/gsumKiWTzgu-AjQvtbM0fw ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : How Ethereum Blockchain Can Solve Your Social Media Privacy Problem via @un: q823ilZOAKvLge6VPyLPBA  \\n\\n url: https://t.co/5ruGoZs84jCwCZwBh7lvlw ']},
#  {'nw40p_JtneVKsWnS29QEuw': ['RT @un: jiCrvwK2UQPTuWK2k73zLg : "Blockchain â\x80\x93 Enabling The True Peer To Peer Economy" via @un: 4WDlV2PHnghJZqG3FgsmDg  by Indorse CEO @un: FyUi7BAoq3gdnf0X6spEJw _mosk \\n\\n url: https://t.co/0gX6dtMKdwCmK871IXlpbA ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Incredibly humbled and thankful for the community support for Indorse - A note from our CEO @un: FyUi7BAoq3gdnf0X6spEJw _mosk!\\n\\n url: https://t.co/jZuvGmH4tqIMQMkW77koKw â\x80¦',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Indorse Dev Updateâ\x80\x8aâ\x80\x94â\x80\x8a13 August 2017 \\n\\n url: https://t.co/q1MAMSSr2wl9_bKmWSeWaQ ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Indorse IND tokens will be tradeable on @un: O-pbuegIGiElqUvSGBgbpw  once theyâ\x80\x99re transferable (7 days after the end of the token saâ\x80¦ ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Listen to our CTO @un: yuMzDTFTid0ctUJkPeA-tw  talk about @un: jiCrvwK2UQPTuWK2k73zLg  platform on @un: g9usm0klRfwR8vP2WaoAYQ  Podcast!\\n\\n url: https://t.co/6wI_ABhbkHOaLWAl5o4wfg ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : 35 Great Business To Watch, September Business Showcase | Thanks for featuring Indorse, @un: LPznlvRwPVYK4cOhs_t-dA _TechNews ð\x9f\x99\x8c\\n\\n url: https://t.co/B-Aa_xkptz7wdXU9DXhEBg â\x80¦',
#    'RT @un: KJ_-sqdFzPUcqJopf0fjgg _vision: Thank you for been involved #cryptocurrency #ico #Ethereum #Bitcoin  url: https://t.co/3MZaJZo_dM5spDjVCUGngA ',
#    'RT @un: KJ_-sqdFzPUcqJopf0fjgg _vision: Now #GenesisVision is genuinely secure. Konstantin Gladych has become our #escrow. #cryptocurrency #ico #btc #ethâ\x80¦ ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Announcing the Gimli @un: xiFrOvKhPty_MXFlnvf8Dw  partnership with Indorse \\n\\n url: https://t.co/83McsgfCY6gDOVWbNWap7A ',
#    'RT @un: KJ_-sqdFzPUcqJopf0fjgg _vision: Genesis Vision announces the launch of a graphic art #contest - Creative Vision! Learn more:â\x80¦ '],
#   'kzNV-XSso47IACPw_z27QA': ['RT @un: jiCrvwK2UQPTuWK2k73zLg : "How Blockchain Will Shape the Future of Social Networks" by Indorse CTO @un: yuMzDTFTid0ctUJkPeA-tw  in @un: i4Iw8QQdUd_bfVmGkjBkHA  ð\x9f\x91\x8d\\n\\n url: https://t.co/jpfd9yOsY_bYG7iZCdjVBw â\x80¦',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Indorse getting a special mention in @un: HKI2PxPzOCifW_35gAtziw  ð\x9f\x99\x8c  url: https://t.co/0nK-T2iCYpDMdwkpIOrGFA ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : @un: L3ixWx2k1QJJbeIm-NfXsw  You can join Indorse slack here:  url: https://t.co/6CuYN8saBdyZmPIgZMVSOA ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : "Professional social networking platform Indorse launches token sale" via @un: YIx9FUHc95fuE-6aths-0A  | 41% of hard cap reached\\n\\n https:â\x80¦',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Indorse Dev Updateâ\x80\x8aâ\x80\x94â\x80\x8a13 August 2017 \\n\\n url: https://t.co/q1MAMSSr2wl9_bKmWSeWaQ ',
#    "RT @un: KJ_-sqdFzPUcqJopf0fjgg _vision: Such gifts don't have a token value :)\\nThank our fan for such vision! \\n url: https://t.co/5w5X-IjnxWZgH4UQ5S84Hw ",
#    'RT @un: c6X2sn6qieEyDldSF5tqcA : "The #blockchain 2day is similar 2 the Internet in the 90\'s: technically- it works, but there\'re no known end-user appliâ\x80¦',
#    "RT @un: cNuTJcZXqrUeIsXjcQmXYw _pro: What exactly is a #smartcontract? Now you'll know  url: https://t.co/vRwPkIU4dS_qrEzCBiZzag ",
#    'RT @un: d917JOLJaMAhV3nkFSyNZw _Ecosystem: â\x9a¡ï¸\x8fAnnouncing the integration of the Bancor Protocol by @un: c6X2sn6qieEyDldSF5tqcA  to allow for Inter-Chain Liquidity  url: https://t.co/dChVSr8nnuDEYMowV4Ukbg â\x80¦',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Building Indorseâ\x80\x8aâ\x80\x94â\x80\x8aBackground, Token Sale &amp; Future\\n\\n url: https://t.co/oNgBXqK20xxDqL_-ncsWRg ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Please take this short survey to help us understand and create a report on how people use endorsements currently!  \\n https:â\x80¦',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : "How Singapore became a hot ICO destination" in @un: wpipFxSA4WETiPYqCaWrhw  by Indorse CEO @un: FyUi7BAoq3gdnf0X6spEJw _mosk \\n\\n url: https://t.co/8f7TMT-NkuFtJsaHE-5hMg ',
#    'RT @un: jiCrvwK2UQPTuWK2k73zLg : Indorse token IND is now live on @un: UkptiGwWxoUFH3gycWx4Kg  ð\x9f\x99\x8c\\n\\n url: https://t.co/TV31mz0KBMHBFej66T14vA   url: https://t.co/4M3x9R6eO3QkzzpkVRat5Q ']}]
