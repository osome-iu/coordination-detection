# %% [markdown]
# # Case Study 5: Activity Synchronization

# %% [markdown]
# ``Pump \& dump" is a shady scheme where the price of a stock is inflated by simulating a surge in buyer interest through false statements (pump) to sell the cheaply purchased stock at a higher price (dump). Investors are vulnerable to this kind of manipulation because they want to act quickly when acquiring stocks that seem to promise high future profits. By exposing investors to information seemingly from different sources in a short period of time, fraudsters create a false sense of urgency that prompts victims to act.
#
# Social media provides fertile grounds for this type of scam. We investigate the effectiveness of our approach in detecting coordinated cryptocurrency pump \& dump campaigns on Twitter. The data was collected using keywords and cashtags (e.g., \$BTC) associated with 25 vulnerable cryptocoins as query terms. We consider both original tweets and retweets because they all add to the stream of information considered by potential buyers. More details on the dataset are found in

# %% [markdown]
# | **Conjecture**       | Synchronous activities       |
# |-----------------------|------------------------------|
# | **Support filter**    | Accounts with < 8 tweets    |
# | **Trace**             | Tweet timestamp             |
# | **Eng. trace**        | 30-minute time intervals    |
# | **Bipartite weight**  | TF-IDF                      |
# | **Proj. weight**      | Cosine similarity           |
# | **Edge filter**       | Keep top 0.5% weights       |
# | **Clustering**        | Connected components        |
# | **Data source**       | DARPA SocialSim             |
# | **Data period**       | Jan 2017--Jan 2019          |
# | **No. accounts**      | 887,239                     |
#
# *Table: Case study 5 summary*

# %% [markdown]
# ## Detection
#
# We hypothesize that coordinated pump \& dump campaigns use software to have multiple accounts post pump messages in close temporal proximity. Tweet timestamps are therefore used as the behavioral trace of the accounts.
# The shorter the time interval in which two tweets are posted, the less likely they are to be coincidental. However, short time intervals result in significantly fewer matches and increased computation time. On the other hand, longer (e.g., daily) intervals produce many false positive matches. To balance between these concerns, we use 30-minute time intervals.
#
# Intuitively, it is likely that any two users would post one or two tweets that fall within any time interval; however, the same is not true for a set of more tweets. To focus on accounts with sufficient support for coordination, we only keep those that post at least eight messages. This specific support threshold value is chosen to minimize false positive matches
#
# The tweets are then binned based on the time interval in which they are posted. These time features are used to construct the bipartite network of accounts and tweet times. Edges are weighted using TF-IDF. Similar to the previous case, the projected account coordination network is weighted by the cosine similarity between the TF-IDF vectors. Upon manual inspection, we found that many of the tweets being shared in this network are not related to cryptocurrencies, while only a small percentage of edges are about this topic. These edges also have high similarity and yield a strong signal of coordination. Thus, we only preserve the 0.5\% of edges with largest cosine similarity

# %% [markdown]
# # Helper functions

# %%
import sys
import glob
import argparse
import numpy as np
import pandas as pd
from sparse_dot_topn import sp_matmul_topn
from tqdm import tqdm
from os.path import join
from itertools import combinations
from scipy.sparse import csr_matrix
from sklearn.feature_extraction.text import TfidfVectorizer


def counters2edges(counter_dict, p1_col, p2_col, w_col):
    # Count how many times each feature co-occurs with each user
    edge = pd.DataFrame.from_records(
        [
            (uid, feature, count)
            for uid, feature_counter in counter_dict.items()
            for feature, count in feature_counter.items()
        ],
        columns=[p1_col, p2_col, w_col],
    )
    return edge


def prepare_content(in_fp, tqdm_desc="parse raw content", tqdm_total=None):
    # construct uid - feature - count table using the defined counters2edges() function
    user_features = defaultdict(lambda: defaultdict(Counter))
    n = 0
    idx = 0
    for line in tqdm(in_fp, desc=tqdm_desc, total=tqdm_total):
        twt = json.loads(line)

        if "timestamp_ms" in twt:
            try:
                # user_id = twt['user']['id_str_h'] #TODO: uncomment
                user_id = twt["user"]["id_str"]
                twt_time_str = twt["timestamp_ms"][:-3]
                created_at = int(twt_time_str)
            except:
                print(f"pass {idx}")
                idx += 1
                continue

            # find min time
            if n == 0:
                min_time = created_at
            # convert the time to the nearest 30 minutes
            if ((created_at - min_time) % 1800) == 0:
                user_features["tweet_time"][user_id][created_at] += 1
            else:
                if created_at < min_time:
                    time_bin = math.ceil((created_at - min_time) / 1800)
                if created_at > min_time:
                    time_bin = math.floor((created_at - min_time) / 1800)
                twt_time = min_time + time_bin * 1800
                user_features["tweet_time"][user_id][twt_time] += 1
            n += 1

    return user_features


def dummy_func(doc):
    return doc


def calculate_interaction(
    edge_df,
    p1_col,
    p2_col,
    w_col,
    node1_col,
    node2_col,
    sim_col,
    sup_col,
    tqdm_total=None,
    tqdm_desc="calculating interaction",
):
    """
    calculate interactions between nodes in partition 1

    input:
        edge_df : dataframe that contains (p1, p2, w)
        p1_col : column name that represent p1, i.e: uid
        p2_col : column name that represent p2 , e.g: time
        w_col : column name that represent weight, if None it's unweighted
        node1_col, node2_col: col after projection, both are uid
        supports: dictionary of userids - post count {p1_node: support}
    return:
        interactions : dict { (p1_node1, p1_node2) : interaction_weight }

    assumption:
        1. non-empty inputs: edge_df
        2. p1_node1 < p1_node2 holds for the tuples in interactions
    """
    user_ids, docs = zip(
        *(
            (p1_node, grp[p2_col].repeat(grp[w_col]).values)
            for p1_node, grp in edge_df.groupby(p1_col)
            if len(grp) > 1
        )
    )

    try:
        tfidf = TfidfVectorizer(
            analyzer="word",
            tokenizer=dummy_func,
            preprocessor=dummy_func,
            use_idf=True,
            token_pattern=None,
            lowercase=False,
            sublinear_tf=True,
            min_df=3,
        )
        docs_vec = tfidf.fit_transform(docs)
    except ValueError:
        tfidf = TfidfVectorizer(
            analyzer="word",
            tokenizer=dummy_func,
            preprocessor=dummy_func,
            use_idf=True,
            token_pattern=None,
            lowercase=False,
            sublinear_tf=True,
            min_df=1,
        )
        docs_vec = tfidf.fit_transform(docs)

    results = sp_matmul_topn(docs_vec, docs_vec.T, top_n=100)

    interactions = pd.DataFrame.from_records(
        [
            (
                u1,
                user_ids[u2_idx],
                sim,
                min(supports[user_ids[u1_idx]], supports[user_ids[u2_idx]]),
            )
            for u1_idx, u1 in enumerate(user_ids)
            for u2_idx, sim in zip(
                results.indices[results.indptr[u1_idx] : results.indptr[u1_idx + 1]],
                results.data[results.indptr[u1_idx] : results.indptr[u1_idx + 1]],
            )
            if u1_idx < u2_idx
        ],
        columns=[node1_col, node2_col, sim_col, sup_col],
    )

    return interactions

# %% [markdown]
# ## Count the number of lines to use progress bar (optional)

# %%
fname = "candidates_streaming_data"  # replace with raw_tweets
# get number of tweets
raw_json_gz = f"/Users/baott/tcd/tcd_code/data/{fname}.json.gz"
# number of lines in the input file
numline_file = f"/Users/baott/tcd/tcd_code/data/{fname}.numline"

# %%
! cat {raw_json_gz} | wc -l > {numline_file}

# %%
numline = int(open(numline_file).read().strip())
numline
# Out:
# 652547

# %% [markdown]
# # Step 1. Parse json of tweets to a table of user - feature values
#
# Construct a uid - feature - count table from raw tweets
#
# Input: raw tweet.json.gz files
#
# Output: feature parquets
# In this case study, the feature are the timestamps of tweets that a user posted.
# For other case studies, the features can be different. E.g., in case study 4, the features are the tweet IDs that a user retweeted.

# %%
# path to input parquet file of edge table
infile = raw_json_gz

# number of lines in the input file
numline = numline
# column name of nodes in partite 1 and 2
p1_col = "uid"
p2_col = "feature"
# column name of edge weights
w_col = "cnt"

feature = "tweet_time"
# read input
with gzip.open(infile, "rb") as in_fp:
    # do work
    user_features = prepare_content(in_fp, tqdm_total=numline)

# write output
for feature, counter_dict in user_features.items():
    edge_df = counters2edges(counter_dict, p1_col, p2_col, w_col)

    fname = "{}.edge.parquet".format(feature)
    edge_df.to_parquet(join(outdir, fname))
# Out:
# parse raw content:  16%|█▌        | 104948/652547 [00:10<00:52, 10356.18it/s]

# %%
edge_df_name = f"{outdir}/{feature}.edge.parquet"

# %% [markdown]
# ## Let's take a look at the feature dataframe

# %%
pd.read_parquet("../features/pnd/tweet_time.edge.parquet").head()
# Out:
#                       uid     feature  cnt
# 0  4OVTHrO8tazRZibJuR2OOg  1491409852    1
# 1  4OVTHrO8tazRZibJuR2OOg  1491445852    1
# 2  4OVTHrO8tazRZibJuR2OOg  1493334052    1
# 3  4OVTHrO8tazRZibJuR2OOg  1491343252    2
# 4  4OVTHrO8tazRZibJuR2OOg  1492144252    1

# %% [markdown]
# # Step 2. Calculate the similarity between features
#
# We consider each user as a document, and "words" are the feature scores, i.e., time intervals.
# - We first filter out users with lack of support, i.e., those posting less than `sup_thresh = 8`
#
# - We then create a TF-IDF vector for each user, where each dimension is a time interval, and the value is the number of tweets in that time interval.
#
# We output a dataframe with the following columns: `user1, user2, similarity, support`; where each record represents an interaction between `user1` and `user2`; `similarity` is the strength of connections and `support` is the post count of `user1`

# %%
# column name of node1, node2, similarity, support
node1_col = "user1"
node2_col = "user2"
sim_col = "similarity"
sup_col = "support"
sup_thresh = 8
# takes a .parquet file of edge table
# save to output file of interactions with p-values
interaction_file = f"{outdir}/{feature}.interactions.parquet"
outfile = interaction_file
# read input
edge_df = pd.read_parquet(edge_df_name)

if not (len(edge_df) > 0 and np.any(edge_df.groupby(p1_col).size() > 1)):
    raise ValueError(
        "Empty input edge table. Run `prepare_content()` to create edge table first"
    )
else:
    # calculate the support, which is the post count for each user
    supports = edge_df.groupby(p1_col)[w_col].sum().to_dict()
    print("No users: ", len(supports))
    # filter nodes based on support
    supports = {k: v for k, v in supports.items() if v > sup_thresh}
    print(f"No users after filtering with threshold={sup_thresh}: {len(supports)}")
    filtered_nodes = list(supports.keys())
    # remove the nodes with low support from edge_df
    edge_df = edge_df[edge_df[p1_col].isin(filtered_nodes)]

    # calculate similirity between users
    interaction_df = calculate_interaction(
        edge_df, p1_col, p2_col, w_col, node1_col, node2_col, sim_col, sup_col
    )
    # write output
    interaction_df.to_parquet(outfile)

# %% [markdown]
# # Let's take a look at the interaction df

# %%
interaction_df = pd.read_parquet(
    "../features/pnd/filter_support.tweet_time.interactions.parquet"
)
interaction_df.head()
# Out:
#                     user1                   user2  similarity  support
# 0  ---7ozV6QOWYeeNpX3s_Yw  yEQ29U-82sbvEDZfwApHdA    0.082107        9
# 1  ---7ozV6QOWYeeNpX3s_Yw  j1Vd4_5A3BaE8VSqaQysfw    0.070501        9
# 2  ---7ozV6QOWYeeNpX3s_Yw  PKD7gEVVncUB4SD_R0ahww    0.145915        9
# 3  ---7ozV6QOWYeeNpX3s_Yw  P2dJ8F5ig5dAwosHqXAVTQ    0.077978        9
# 4  ---7ozV6QOWYeeNpX3s_Yw  L7FI6SkWiZ4Mxb433r-g7g    0.073727        9

# %% [markdown]
# # Step 3. Filter low edge weight and create a network
# For case study 5, we apply an weight filter `sim_thresh = 0.995`, i.e., only accounts with similarity >0.995 percentile are considered

# %%
# path to input indexed text of tweets
twttext = f"{outdir}/table.by.user.pkl"

# path to output file of the graphml for Gephi visualization
outgraph = f"{outdir}/{feature}.filtered.coord.graphml"
# path to output file of context of each suspicious group
grouptext = f"{outdir}/{feature}filtered.coord.pkl"

# read input parquet file of interaction
interaction_df = pd.read_parquet(interaction_file)

# define the filters
sim_thresh = 0.995
# Out:
# <class 'networkx.classes.graph.Graph'>
# 13

# %%
# apply edge weight filter: 0.995 quantile cosine similarity of TFIDF vectors
interaction_df = interaction_df[
    interaction_df[sim_col] >= interaction_df[sim_col].quantile(sim_thresh)
]
# create a graph object from the interaction table
G = nx.Graph()
for idx, row in interaction_df.iterrows():
    try:
        G.add_edge(
            row[node1_col], row[node2_col], weight=row[sim_col], support=row[sup_col]
        )
    except:
        print(row)
        pass
#  write graph object to file
nx.write_gml(G, outgraph)
del interaction_df

# get the tweet texts for each connected component for manual annotation
has_text = twttext is not None
if has_text:
    with open(twttext, "rb") as f:
        tweet_table = pickle.load(f)
# texts (list of dict): each element is a connected component
# represented by a dictionary where each key is a node_id and the value is the tweet text
texts = [
    {node_id: tweet_table[node_id] for node_id in component}
    for component in nx.connected_components(G)
]
texts.sort(key=len, reverse=True)
# save to file
with open(grouptext, "wb") as f:
    pickle.dump(texts, f)

# %% [markdown]
# # Note
#
# The above code matches the filtering procedure described in the paper:
# 1. users with low support (few posts) are removed
# 2. tf-idf vectors are calculated
# 3. similarity between tf-idf vectors are calculated, and edges with low similarity are removed.
#
# The results of case study 5 in the paper were obtained by a slightly different ordering of these steps:
# 1. tf-idf vectors are calculated
# 2. similarity between tf-idf vectors are calculated, and edges with low similarity are removed
# 3. users with low support are removed.
#
# The resulting networks are very similar, and the result reported in the paper are not affected by this change.

# %% [markdown]
# # Optional final step: save user_id and tweet texts
#
# For optional close-reading of the case study, we parse the raw json of tweets to a table of user_id - tweet text and save to file

# %%
#!/usr/bin/env python3
import re
import os
import sys
import gzip
import pickle
import argparse
import pandas as pd
import ujson as json
from tqdm import tqdm
from os.path import join
from collections import defaultdict, Counter
import math
import pyarrow
import numpy as np
import networkx as nx

# path to output directory for output randomized edge tables
outdir = "12-04-2024_features"
if not os.path.exists(outdir):
    os.makedirs(outdir)


def prepare_content(in_fp, tqdm_desc="parse user tweet", tqdm_total=None):
    # create a dictionary of user_id -> list of tweets by that user
    user_tweets = defaultdict(list)
    idx = 0
    for line in tqdm(in_fp, desc=tqdm_desc, total=tqdm_total):
        twt = json.loads(line)
        try:
            # user_id = twt['user']['id_str_h']
            # user_tweets[user_id].append(twt['text_m'])
            user_id = twt["user"]["id_str"]
            user_tweets[user_id].append(twt["text"])
        except:
            pass

            idx += 1
            print(f"pass {idx}")
    return user_tweets


# path to input parquet file of edge table
infile = raw_json_gz
# path to output pickle file of tweet table
outfile = f"{outdir}/table.by.user.pkl"


# read input to create a dictionary of user_id -> list of tweets by that user
with gzip.open(infile, "rb") as in_fp:
    # do work
    user_tweets = prepare_content(in_fp, tqdm_total=numline)
with open(outfile, "wb") as out_fp:
    # write output
    pickle.dump(user_tweets, out_fp)
# Out:
# parse user tweet:   1%|▏         | 8209/652547 [00:00<00:57, 11155.01it/s]
# pass 1
# pass 2
# parse user tweet:   2%|▏         | 12907/652547 [00:01<00:57, 11201.46it/s]
# pass 3
# pass 4
# pass 5
# pass 6
# pass 7
# pass 8
# parse user tweet:   2%|▏         | 15473/652547 [00:01<00:52, 12049.13it/s]
# pass 9
# pass 10
# parse user tweet:   3%|▎         | 19062/652547 [00:01<00:53, 11752.45it/s]
# pass 11
# pass 12
# pass 13
# pass 14
# pass 15
# pass 16
# pass 17
# pass 18
# pass 19
# pass 20
# pass 21
# parse user tweet:   3%|▎         | 21398/652547 [00:01<00:56, 11153.23it/s]
# pass 22
# pass 23
# pass 24
# pass 25
# pass 26
# pass 27
# pass 28
# pass 29
# pass 30
# pass 31
# parse user tweet:   4%|▍         | 24724/652547 [00:02<01:06, 9394.61it/s]
# pass 32
# pass 33
# pass 34
# pass 35
# pass 36
# pass 37
# parse user tweet:   4%|▍         | 26784/652547 [00:02<01:09, 9036.33it/s]
# pass 38
# pass 39
# pass 40
# pass 41
# parse user tweet:   4%|▍         | 28934/652547 [00:02<01:02, 9919.40it/s]
# pass 42
# pass 43
# pass 44
# pass 45
# pass 46
# pass 47
# pass 48
# parse user tweet:   5%|▍         | 31337/652547 [00:02<00:56, 10984.32it/s]
# pass 49
# pass 50
# pass 51
# pass 52
# pass 53
# pass 54
# pass 55
# parse user tweet:   5%|▌         | 33972/652547 [00:03<00:51, 12085.95it/s]
# pass 56
# pass 57
# pass 58
# pass 59
# pass 60
# pass 61
# pass 62
# pass 63
# pass 64
# pass 65
# pass 66
# parse user tweet:   6%|▌         | 40596/652547 [00:03<00:47, 12795.12it/s]
# pass 67
# pass 68
# pass 69
# pass 70
# pass 71
# pass 72
# pass 73
# pass 74
# parse user tweet:   7%|▋         | 43144/652547 [00:03<00:48, 12544.95it/s]
# pass 75
# pass 76
# pass 77
# pass 78
# pass 79
# parse user tweet:   7%|▋         | 45623/652547 [00:04<00:50, 12043.87it/s]
# pass 80
# pass 81
# pass 82
# pass 83
# parse user tweet:   8%|▊         | 50819/652547 [00:04<00:47, 12658.66it/s]
# pass 84
# pass 85
# pass 86
# pass 87
# parse user tweet:   8%|▊         | 52087/652547 [00:04<00:47, 12522.46it/s]
# pass 88
# pass 89
# pass 90
# pass 91
# pass 92
# pass 93
# pass 94
# parse user tweet:   9%|▊         | 55841/652547 [00:05<00:53, 11157.73it/s]
# pass 95
# pass 96
# pass 97
# parse user tweet:   9%|▉         | 58260/652547 [00:05<00:51, 11548.68it/s]
# pass 98
# pass 99
# pass 100
# pass 101
# pass 102
# parse user tweet:   9%|▉         | 60782/652547 [00:05<00:48, 12079.02it/s]
# pass 103
# pass 104
# pass 105
# pass 106
# parse user tweet:  10%|█         | 65773/652547 [00:05<00:48, 12224.26it/s]
# pass 107
# pass 108
# pass 109
# pass 110
# parse user tweet:  11%|█         | 70928/652547 [00:06<00:46, 12600.37it/s]
# pass 111
# pass 112
# parse user tweet:  11%|█▏        | 74752/652547 [00:06<00:49, 11670.53it/s]
# pass 113
# pass 114
# parse user tweet:  12%|█▏        | 75928/652547 [00:06<00:53, 10729.60it/s]
# pass 115
# pass 116
# pass 117
# pass 118
# parse user tweet:  12%|█▏        | 78104/652547 [00:06<00:55, 10334.63it/s]
# pass 119
# pass 120
# parse user tweet:  13%|█▎        | 83075/652547 [00:07<00:48, 11802.98it/s]
# pass 121
# pass 122
# pass 123
# parse user tweet:  14%|█▍        | 90509/652547 [00:07<00:46, 11990.20it/s]
# pass 124
# pass 125
# pass 126
# pass 127
# parse user tweet:  15%|█▍        | 95418/652547 [00:08<00:47, 11638.98it/s]
# pass 128
# parse user tweet:  15%|█▌        | 100354/652547 [00:08<00:45, 12047.54it/s]
# pass 129
# pass 130
# parse user tweet:  16%|█▌        | 104948/652547 [00:09<00:47, 11416.60it/s]
# pass 131
# pass 132
# pass 133
# pass 134
# pass 135

# %%
user_tweets
# Out:
# defaultdict(list,
#             {'150521075': ['I’m on my way to Bullock County to help get out the vote!  Please remember today (OCT 24th) is the last day to regi… https://t.co/cfeUdgSPfd'],
#              '1400915708259696640': ['RT @willainsworthAL: Addie is super excited to be campaigning with our next U.S. Senator @KatieBrittforAL and former Patriots player @wesle…',
#               'The Port of Mobile has a tremendous positive impact across all 67 counties in our state. This data confirms that th… https://t.co/VZQnkcmahH',
#               'We applaud the Alabama families, teachers, and school administrators who navigated this uniquely challenging time i… https://t.co/1Q619RCJBE',
#               "The Nation's Report Card released today shows that Alabama is the only state nationwide to have fourth grade readin… https://t.co/WOaDCPEGck",
#               'We were excited to be at Hancock Whitney Stadium in Mobile to watch @SouthAlabamaFB and @TroyTrojansFB battle for t… https://t.co/TLOMvGyawJ'],
#              '1199183201719259142': ['RT @Kathy_Congress: Flipping this District Blue, producing Higher paying jobs, and getting better wages for Alabama workers is the reason w…',
#               'RT @joncoopertweets: 🚨 BREAKING: Attorney General Merrick Garland and other senior DoJ officials will hold a press conference at 1:30 pm ET…',
#               '15 Days Till Our Big Midterm Election here in Alabama and I need to raise $1500 before Nov 8 Election Day. Will you… https://t.co/FFzmboq2V6'],
#              '1524935707424342016': ['Thank you @WVTM13 for the opportunity to be featured. Click their tweet for the story/video https://t.co/GKGj9PQILh',
#               'RT @WVTM13: Monday last day for Alabamians to register for general election https://t.co/e1tT5XPeQ2',
#               'RT @caroljsroth: @POTUS The last two years had extraordinary covid spending. Everyone knows this.\nIn 2019, the deficit was an atrocious $98…',
#               "RT @Tim_The_Sandman: @ninaturner To progressives, gov't should provide everything needed in life.\n\nThat's not reality.  It is immoral to st…"],
#              '18061669': ['I’m so thankful for the opportunity to connect directly with so many Alaskans at the Annual @NativeFed Convention.… https://t.co/UcHzRes4is',
#               'I loved attending Quyana at #2022AFN. Seeing dancers from across Alaska perform their traditional Native dances an… https://t.co/ihMObFlc4l'],
#              '151247615': ['Alaska plays an essential role in international relations and national defense. I’m dedicated to enhancing Alaska’s… https://t.co/bfpdiBBOp2',
#               'Today, October 24, marks the first day of #EarlyVoting in Alaska 🗳️ Make your voice heard, &amp; get out and vote! \n\nAl… https://t.co/JSTO2sUVQh'],
#              '1524549352890404864': ["Good morning &amp; happy 1st day of early voting! This year, you have the opportunity to vote for me--I'm here to tell… https://t.co/I5I3m0kjRz"],
#              '1371619745041063937': ["🚨 You don't want to miss this! 🚨 Join President Trump and Kelly Tshibaka for a Tele-rally! TONIGHT at 6PM AKDT.… https://t.co/xBhxPFNY9D"],
#              '1514353565510164482': ['JUNEAU—we just arrived! Thank you all for the warm welcome! \n\nI hope to see you at one of our events while we’re in… https://t.co/WtRdCG0PQp',
#               'One billion crabs didn’t simply “disappear”. \n\nThey were lost as the result of acidic water, mismanagement, and fac… https://t.co/pjgIvxZJwq',
#               'Women in our country shouldn’t have to live in fear over whether or not they’ll have access to reproductive healthcare.'],
#              '65493023': ['Early voting started today! #vote #sarahforalaska #rankthered #voterepublican https://t.co/32x1Xh28cH',
#               'Thank you, always, for that warm Fairbanks welcome! ALWAYS love being in the Golden Heart City! \n#fairbanks… https://t.co/j1F6B4yjy4',
#               'Read the full article ➡️ https://t.co/UirVeESMoY https://t.co/xWF9G8fjqy'],
#              '1324926274888888320': ['A son of two police officers, I know it is crucial that law enforcement has the resources to keep communities safe.… https://t.co/BM48G51Rdx'],
#              '65707359': ['Thanks for having me, Tuba City! https://t.co/lg6rwEITOh',
#               'Mesa’s Dia de los Muertos festival yesterday was so much fun. Proud to represent such a vibrant community. https://t.co/N5cixoqAO1',
#               'RT @GabbyGiffords: From the moment we met, I saw that @CaptMarkKelly and I shared the same dedication to public service. From the Navy to t…',
#               'If you sign up to volunteer, @GabbyGiffords and I might just drop by to give you a yard sign. \n\n👉… https://t.co/FkNNxXmJcI',
#               'Ballots have been hitting mailboxes across Arizona, and there’s still time to request one before Oct 28. If you hav… https://t.co/tkD04dk5P9'],
#              '117338050': ['RT @ThoBishop: "We\'re rooting for you." - @RonPaul to @bgmasters.',
#               'RT @TuckerOriginals: The Candidate. Available Tuesday. @FoxNation https://t.co/sHvYHvWYsR',
#               'RT @approject: OUR CLOSING AD:\n\n"I don\'t have my daughter. She\'s gone now."\n\nTransgenderism is killing kids, and @CaptMarkKelly is part of…',
#               'RT @AZGOP: Today is a great day to vote LAKE, BLAKE, &amp; ABE! \n\n(&amp; Mark, Kevin, Yee, Nick, Paul) \n\nGo to https://t.co/jqmkMCN0Qf to find your…',
#               'RT @EndWokeness: Americans: We can’t afford food\n\nThe White House: https://t.co/oZH6sMEn3B',
#               'RT @jeremiahcota: I will be voting straight R, up and down the ballot. https://t.co/Op5WubeK0u',
#               'RT @MastersPress: Arizona‘s Blake Masters: Momentum Behind Our Campaign Is ‘Undeniable‘ https://t.co/WzSVzVWRff',
#               'RT @VoteMarsha: It was great to stop by and meet with some mamma bears in Arizona!\xa0\n\nThese women are working hard to be sure we elect stron…'],
#              '4608082538': ['Happy #Diwali to all who celebrate, in Arizona and across the world! May the Festival of Lights bring you joy and peace.',
#               'What a week! Below are some highlights: visiting the Laguna Elementary School Days of Caring Project, attending the… https://t.co/TjCzg992Av'],
#              '2966570782': ['The way to end a war? Win it quickly. \n\nHow is it won quickly? By giving Ukraine the weapons to defeat Russia. https://t.co/EJEwif3VJj'],
#              '49217025': ['@repcampbell @JeremyZegas82 @TimBourcet @readytoplow https://t.co/HuOTCMXjbZ',
#               'RT @RubenGallego: Or a go on a date…. Sorry forgot these guys aren’t a “catch” in the dating market.  \n\n“So what do you do for fun?” \n\n“I s…',
#               'Or a go on a date…. Sorry forgot these guys aren’t a “catch” in the dating market.  \n\n“So what do you do for fun?”… https://t.co/mfc3geIQo9',
#               'RT @RepElaineLuria: Big news! \n\nPresident Biden signed my bipartisan Veterans’ Compensation Cost of Living Adjustment Act of 2022 into law…',
#               "RT @NateSilver538: There was like this 10-day stretch where nearly every poll was a disaster for Democrats but for the past few days, it's…",
#               'Justice Thomas is corrupt. https://t.co/lWP3UTlJJD',
#               'RT @PinalDems: Pinal County was the place to be over the weekend. The Blue Jean Gala was a huge success. Thank you Sponsors and Attendees f…',
#               'RT @malcolmkenyatta: Before Dr. Oz starts lying he’s not a Phillies fan.'],
#              '816652616625168388': ['Today, I sent a letter to Biden’s @HHSGov regarding its laissez-faire attitude towards the welfare of unaccompanied… https://t.co/bP4ThSjWfj',
#               'The Biden Administration has created the worst border crisis in American HISTORY and continues to try to deceive th… https://t.co/qPCpfld0Qk',
#               "Instead of focusing on America's economic, border, or crime crises, Biden is focusing on mutilating American childr… https://t.co/rO7d6pzUdN",
#               'Those downplaying the severity of the Biden Border Crisis have never been to the border and will never go. \n\nThey s… https://t.co/yy0IRoucOo',
#               'Liberals preach "tolerance" but are the least tolerant people in America. https://t.co/j09NA2sM6p',
#               'Never happened. \n\nMy colleagues and I would never let this happen. https://t.co/3lBHnRpu0H',
#               'Malicious individuals are attempting to infiltrate our country at a higher rate than ever. \n\nNearly 100 terrorists… https://t.co/Hk9reuwcST'],
#              '702601370344402944': ['Thank you @BurgessOwens for coming to our campaign office to fire up our volunteers! Only 15 days until we turn Ari… https://t.co/qJbic8NKw6'],
#              '1236122354285072385': ['1 vote in 15 days will last a lifetime! https://t.co/Xe0k5gSLU7',
#               'RT @VotersTomorrow: Vote for the side whose entire platform isn’t taking away the rights of women, immigrants, the LGBTQ+ community, worker…',
#               'American Dream: Javier Ramos\n\nhttps://t.co/2cXCrDWrIm',
#               '@Deanne54321 Haha, Tucson is outside the district.',
#               '@Deanne54321 Mesa',
#               'RT @NeuroSpark: There is no red wave. There is no shift to the right. The polls are tightening as they always do before an election. In rea…',
#               'RT @debbie156: @azdemparty @KariLake https://t.co/eMgt51sybo',
#               'RT @krismayes: No, Abe. The biggest threat to our democracy is a woefully inexperienced, lying, election denying, Trump-endorsed sock puppe…',
#               'Do not give up! Participate in our democracy. Elect leaders who have the best interest of the people above profits… https://t.co/TYtqkjht02',
#               'Meeting voters at Mesa’s Dia de Los muertos festival: https://t.co/m2TZlMT0DG'],
#              '872148729184362497': ['In 2021 Arizona was mentioned as potentially getting an additional Congressional seat, but got nothing. \n\n“Phoenix… https://t.co/bgWYlHiGPl',
#               'Live footage of independent voters flocking to @KariLake https://t.co/C3pPkKTPGs',
#               'You also drove the elections process into the ground with your incompetence.  6,000 wrong ballots and malpractice i… https://t.co/izV0KnDXeF'],
#              '28602948': ['RT @POTUS: We know what Republicans in Congress will do if they get their way. They’re telling us.\n \nThey’re going to cut Social Security a…',
#               'While Democrats are fighting to prevent gun violence and ban assault weapons, extremist Republicans have sided with… https://t.co/z01Ke0H7uf',
#               'RT @SecCardona: Today’s temporary decision does not stop the Biden Administration’s efforts to provide borrowers the opportunity to apply f…'],
#              '2573587962': ["We're nearly 2 weeks out from Election Day! 🗳️\n\nI'm so thankful for the tireless work of our field team, especially… https://t.co/4XTNHE2BTT"],
#              '1415011405544177667': ['RT @EliCrane_CEO: In Pinal County for more stops across the district. @sherifflamb1 joined me and @RepWesterman for a helicopter tour of th…',
#               'RT @EliCrane_CEO: Very honored to have @RepWesterman, the Ranking Member of the House Committee on Natural Resources, here touring the dist…',
#               "RT @michaelgwaltz: I'm proud to support a new generation of veterans through Front Line Patriots to get our country back on track.\n\nWe are…"],
#              '1080885078425784320': ["HEADS UP: If you're an #AZ09 student looking to earn a Congressional nomination for one of our nation's military ac… https://t.co/Wl9nx6My4X",
#               "Great to tour @Honeywell_Aero’s Phoenix headquarters and speak with some of their hardworking employees.\n\nI'll keep… https://t.co/KNmGH6uDKt",
#               'Diwali reminds us that light always triumphs over darkness.\n\nIt was a pleasure to join @MayorGallego and my friends… https://t.co/785fhEINXW'],
#              '218292287': ['Honored to receive the endorsement from the @tempechamber. \n\nSupporting local businesses and creating high wage job… https://t.co/jIuPx817Dy',
#               'I appreciate the ❤️, @StevenHorsford. I look forward to continue working with you to protect the Colorado River in… https://t.co/YYxw3KJQhJ'],
#              '1433165953429393411': ['The people of my district are my friends, my neighbors, my community. I live and work here with my family. We want… https://t.co/peWGSHW7wb',
#               'With just over two weeks to go, for those planning to vote early please go return your ballot! On to victory!… https://t.co/2LOloGLTSV',
#               'RT @RXgop: It’s so easy! Let’s do this!\n\nTonight 10/24 &amp; Wednesday 10/26\n\nCD4 RNC Victory office \n5041 E Elliot Rd\nPhoenix, AZ 85044\nNext t…',
#               'https://t.co/I9ekkvDnkl',
#               'Nancy pelosi and her lapdog, Greg Stanton, have ignored and even diverted attention away from the economic crisis f… https://t.co/9ef9OQpS5c'],
#              '5558312': ['This #DownSyndromeAwarenessMonth we take the opportunity to celebrate those with Down syndrome. They lead fulfillin… https://t.co/T7rBhk8X09',
#               'Thirty years ago, polio was paralyzing 1,000 children in 125 countries every single day. Today, that number has fal… https://t.co/XN0sfM4Uib',
#               "Thanks to @dodpaa's efforts another Arkansas family was finally able to mark the return of their loved one, US Army… https://t.co/ByZ60XOnVU"],
#              '111671288': ['Early voting has started, and I encourage Arkansans to vote NO on Issue 4. Easy access to marijuana will be bad for… https://t.co/JXgQCZVrnb'],
#              '1397725068738826240': ['RT @cadams1555: There we go! Over 250 votes cast a little after noon in our small county. Checked all the boxes! @JonesForAR @AnnaBethforAR…',
#               'RT @janrobinjackson: @MairseyDotes @JamesForAR @JonesForAR @AnnaBethforAR @JesseGibson4AG @Kelly4Arkansas @GoldiGaines @Lauren4Arkansas htt…',
#               "RT @ChrystalChipria: It's that time of year, VOTING SEASON and Starts Early Voting TODAY!! Make a plan, print out your sample ballot, go ou…",
#               'RT @MairseyDotes: Get on out there! #iVoted for some of the best candidates #Arkansas has ever had! @JonesForAR @AnnaBethforAR @JesseGibson…',
#               'RT @FrederickKelsi: Early voted today! @JesseGibson4AG @JonesForAR @Kelly4Arkansas @JamesForAR',
#               'RT @mcbmd: Couldn’t wait to #VoteEarly &amp; #VoteBlue! @JonesForAR @Kelly4Arkansas @JamesForAR @Lauren4Arkansas @JoshMoodyAR @caitlin_oxford h…',
#               '@kylegriffin1 Help us to reach more voters so that we can double that number and save democracy. \n\nhttps://t.co/yPAKRZe8x4',
#               '💙💙 https://t.co/4qKOuxpoH2',
#               'RT @grant4arkansas: Did my part and voted first thing this morning! 😊 @JonesForAR @Kelly4Arkansas @JamesForAR @JesseGibson4AG @AnnaBethforA…',
#               '@SusyofAR 💙',
#               '💙💙💙🙌🏾🙌🏾💙💙💙 https://t.co/2XE6B7lyZo',
#               'I can not wait to see the numbers tomorrow! https://t.co/9H1fVSzbAq',
#               'The face you make when your opponent tells you to “get your act straight” after you pointed out their hypocrisy 😏 https://t.co/HksiJr0of9',
#               '@nathanwfoster @SimonWDC @JonesForAR @DrQHathaway @AnnaBethforAR @JesseGibson4AG @Kelly4Arkansas 💙💙 I love to see it!',
#               'RT @nathanwfoster: Took @SimonWDC advice to heart and voted in the first hour of the first day in AR for @JonesForAR @JamesForAR @DrQHathaw…',
#               '@Loveamethyst90 💙💙💙 \nyes ma’am, I am here for it! We are getting our act straight in the voting booth 🙌🏾💙',
#               '@NamowLived @MonteforAR 🙌🏾',
#               '🚨🗣 It’s Happening!! https://t.co/CsFooHJcq3',
#               "RT @GetLoudArkansas: Hey fam, it's finally here! Early voting starts today. Make sure to grab your ID when you head to the polls and screen…",
#               'RT @IrvinCamachoAR: Tomorrow I’ll be voting for:\n@JonesForAR \n@Kelly4Arkansas \n@DianaForAR\n @JoshMoodyAR \n@JamesForAR \n@Lauren4Arkansas \n\nI…',
#               '@JoeBiden Early voting has begun and we are still hitting the ground hard letting people know they can have a Senat… https://t.co/HIMZLODX4N',
#               '@POTUS My opponent voted against it, &amp; also voted against Arkansans &amp; Americans needs. Early voting has begun &amp; we… https://t.co/4uPMp976wU',
#               'Early voting has begun and we are still hitting the ground hard letting people know they can have a Senator who car… https://t.co/vclAeGNp9i',
#               'Bipartisan Infrastructure Law replaces lead pipes across America because every person &amp; every child in this country… https://t.co/r5ZCzgMWBv',
#               'It is that time #Arkansas, early voting has begun! \nLet’s see those I voted early pictures💙\U0001faf6🏾\n#arpx',
#               'RT @JoeBiden: Whether you’re an early voter or showing up on Election Day—get to the polls and make your voice heard.',
#               'RT @POTUS: My Bipartisan Infrastructure Law replaces lead pipes across America because every person and every child in this country should…'],
#              '2234890814': ['"An Early Voting Message" \nFrom The Campaign To Elect @DrQHathaway To The U.S. Congress #AR02 #VoterSuppression… https://t.co/v5asq0EkxQ',
#               '@nathanwfoster @SimonWDC @JonesForAR @JamesForAR @AnnaBethforAR @JesseGibson4AG @Kelly4Arkansas Thanks for your vote, Mr. @NathanWFoster!'],
#              '2953974395': ['Diwali is a joyous celebration that leads us to light, good deeds, brightness, and prosperity. \n\nFor all of our Ind… https://t.co/L82L86HCRY',
#               'As a proud member of @Rotary, the eradication of polio is a cause that I am passionate about. \n\nToday is World Poli… https://t.co/zZMhvyx4va',
#               'RT @PunchbowlNews: Join us on Thurs., Oct. 27 at 9 a.m. ET for a convo w/ @RepFrenchHill about issues facing American workers, including he…'],
#              '1740229652': ['Early voting in Arkansas has officially  started! Contact your County Clerk for voting times and locations.\n\nI woul… https://t.co/U97aUE7aG9'],
#              '1495789061797203970': ['@BuenoForMiami https://t.co/acDx6jFah1',
#               'RT @BuenoForMiami: Why are 3rd parties blocked in the media and why is it harder to run as an independent? \n\nBecause giving you the ILLUSIO…',
#               '@BearDownCSFA @beinlibertarian https://t.co/QthU5PlhIx',
#               '@BearDownCSFA @beinlibertarian Show us on the doll where the beard dye touched you. 🤣',
#               '@BobToye @ComicDaveSmith Rumor is "he doesn\'t dye it... he lives it." 😉',
#               'If only someone had warned them... https://t.co/muVXv4XMkx',
#               'Early voting starts TODAY in #Arkansas . Withdraw your consent from a broken system and elect Michael White. The fu… https://t.co/ph7t4DTqlq',
#               '@IrvinCamachoAR And why do I think "one and done"? Big business and big government love each other. Once a monopoly… https://t.co/ClYMXLw7M4',
#               "@IrvinCamachoAR I am all for legalization, yet on principle I just don't believe it goes far enough. It ignores pre… https://t.co/BuhOqZlUMc",
#               '@HighImpactFlix Thanks for covering it! And it was balanced commentary too that covered what I did well and could h… https://t.co/Z1EAlOzPl5'],
#              '1394328556570882056': ['As a mother and a democrat, I am ready to get to Congress and fight for our residents. This includes codifying Roe… https://t.co/QXETZe11qy',
#               '🚨 With 15 days left before Election Day, my race has become closer than ever. I am the mother, wife, and Democrat w… https://t.co/0KR8HNLZQf',
#               'Early voting starts today! Do you have a plan to vote between today and November 8th? #Midterms https://t.co/dmrBWBUGhx',
#               'RT @JimHendren1: Politicians asking voters to pass an amendment with 50% + 1 that will raise requirement to 60% for any future law changes…',
#               'RT @IrvinCamachoAR: Tomorrow I’ll be voting for:\n@JonesForAR \n@Kelly4Arkansas \n@DianaForAR\n @JoshMoodyAR \n@JamesForAR \n@Lauren4Arkansas \n\nI…'],
#              '234469322': ["Begging adversaries for oil and draining emergency reserves is no strategy. Yet, that's POTUS Biden's plan. Domesti… https://t.co/eTJQ8uyS2D",
#               'Democrat policies are to blame for the record-breaking crisis at our southern border.\n\n@HouseGOP solutions:\nFinish… https://t.co/P2rypLViqv',
#               'RT @HouseAgGOP: This year, American families will face the HIGHEST #inflation rate in candy since the data was first recorded—making this t…',
#               "How can the White House claim the border is secure? \n\n227,547 illegal encounters in September alone. That's close t… https://t.co/SVrrpL7JAd"],
#              '1592481150': ['Honored to once again receive an endorsement from @ArkansasOnline to represent the constituents of the 4th district… https://t.co/WlAYZJUR57'],
#              '40039456': ['@joncoopertweets What does hate and dissension accomplish.? https://t.co/3N4kDIoion'],
#              '1351236267707654145': ['Californians are feeling the impact of increasingly catastrophic wildfires. \n\nMy bill, the FIRE Act, allows FEMA to… https://t.co/Zus5v1uNxI',
#               'Wishing a happy and prosperous #Diwali to all who are celebrating! https://t.co/fitsEarqKU',
#               'It was an honor to welcome @VP back home to California for an important discussion on defending reproductive rights… https://t.co/5ykBWe9cDt'],
#              '545030277': ['Thank you @POTUS \n\nIt is time for real leadership that will represent the people rather than the special interest w… https://t.co/fbJ0Cz9WdW',
#               '15 days until the election.\n\nSo far 552,843 Democrats have voted in CA.\nLast year in the recall elections, 2,294,05… https://t.co/jlf555qSf0',
#               'I don’t want to hear about “changing the subject” on inflation from someone who has $12 pints of ice cream in her f… https://t.co/AsGkDGSUMX',
#               'Fauci should not be allowed to rewrite history. We must elect U.S. Senators who will agree to do a complete investi… https://t.co/hbEqUQywLL',
#               "RT @SenJohnKennedy: Biden claims he hasn't stopped or even slowed U.S. oil production, but he’s halted new leases to keep drilling at a sta…",
#               '@RNCResearch #25thamendmentnow'],
#              '30216513': ['Law enforcement must hold those responsible accountable, we must continue to secure our Jewish institutions, and al… https://t.co/1f7gP5PR6S',
#               'We must not accept complacency when it comes to the surge in anti-Semitic incidents. Sadly, the Jewish experience i… https://t.co/MLQbiTD3x6',
#               '#HappyDiwali to all those celebrating the #FestivalOfLights - a cherished tradition that serves as a joyful moment… https://t.co/n3L8P1KXTc'],
#              '229020620': ['We have 15 days till the midterms. \n\nCan you help me save your Social Security, Medicare &amp; Medicaid from… https://t.co/Ioyr0Ye2HN',
#               'My wife is disabled. Without Social Security, Medicare &amp; Medicaid we wouldn’t be able to afford the care that she n… https://t.co/Psq4kQpKL9'],
#              '816833925456789505': ['Residentes de CA: Hoy es el último día para preinscribirse en línea para votar en las elecciones intermedias. Puede… https://t.co/ITs7YEGG6B',
#               'CA Residents: Today is the last day to pre-register online to vote in the midterm elections. You can check your reg… https://t.co/cQW2LYsDKd',
#               'Happy #Diwali to all\xa0who celebrate!\xa0\xa0\n\nWishing\xa0you and your loved ones\xa0a celebration filled with hope and light. https://t.co/YhQkOgEfhu'],
#              '813998038314164228': ['Women’s reproductive rights are one of the most important issues right now. Vote for David Canepa to insure  you ha… https://t.co/KVLaKr8hlx'],
#              '18973663': ['During my 10 years in the State Assembly, I worked hard to secure climate, infrastructure, and transportation fundi… https://t.co/DOyPO1hRa0'],
#              '18120497': ['Proud to have the endorsement of @Everytown and activists across our community who are demanding more action on gun… https://t.co/9eNCxkDOCx',
#               'RT @LongBeachMayor: We want to wish a happy and safe #Diwali\xa0to everyone celebrating the festival of lights here in Long Beach and around t…',
#               'Listen, all I need to make this year perfect is for Democrats to hold the House. 👏🏽👏🏽👏🏽 https://t.co/cJOv4RDPCy',
#               '@megankerr Attacking trans kids is disqualifying. He should be no where near a government role in Long Beach. This… https://t.co/IsEG6thTxE'],
#              '139770510': ['Roberto/Bobby is responsible for policing by his Chief Luna that shot 1 man shot dead and 3 just plain shot. Not sh… https://t.co/JhFrgkWSNY'],
#              '950783972': ['On #WorldPolioDay, it is crucial to reaffirm our commitment to eradicating this disease. \n\nFor more information, vi… https://t.co/098HJZupCA',
#               'Wishing a safe, joyous, and prosperous #DiwaliCelebration to those celebrating in Sacramento, across the country, a… https://t.co/ir12nvvwGe'],
#              '1105326466588323845': ['The “inflation is higher in other countries” argument is completely disingenuous without telling people that every… https://t.co/AEtIcQEGw0'],
#              '1243902714': ['For those celebrating throughout #VenturaCounty and around the world, I hope the Diwali lights brighten your life a… https://t.co/wXrR5uEsrw'],
#              '1183132214680150016': ['To all those celebrating in #CA26 and around the country, have a very happy #Diwali! https://t.co/YGri0nOV9n',
#               'It’s clear: #TeamJacobs has the momentum on our side in one of the most competitive races in America. Chip in now t… https://t.co/Nu1D2ggFTb',
#               '🚨🚨 Far left special interest groups are spending over $400,000 this week to bail out @repbrownley on TV and lie abo… https://t.co/DoDbqB3mVP',
#               'Today is the LAST DAY TO REGISTER to vote in the November 8th Election! \n\nMake sure you’re registered and find more… https://t.co/DsLE4MRww8'],
#              '15764644': ['It was an honor to meet with Ukrainian Speaker @R_Stefanchuk &amp; express America’s admiration for the heroes of Ukrai… https://t.co/BfzsBn0Koi',
#               'The U.S.-German alliance is central to supporting Ukraine, as well as advancing global peace, security and stabilit… https://t.co/OnCmGhWVXT',
#               'Today, I met with Croatian Prime Minister @AndrejPlenkovic &amp; Foreign Minister @GrlicRadman: top officials of a valu… https://t.co/pSRZyzp3gm',
#               'It was a privilege to meet with Speaker of the Croatian Parliament Gordan Jandroković, whose government is hosting… https://t.co/LHroCWGq2t',
#               'Join Prime Minister @AndrejPlenkovic and me for a press conference in Zagreb, Croatia on our nations’ support for t… https://t.co/S7C0QGU8td',
#               'Join Speaker Gordan Jandroković and me in Zagreb, Croatia for remarks on the important relationship between the U.S… https://t.co/bHEGlG0jXk',
#               'Our first stop in Croatia was to greet the patriotic Marine Detachment at @USEmbZagreb.\n\nCongress and the Country a… https://t.co/LqS2sb122n'],
#              '2461810448': ['Happy #Diwali to all who celebrate the Festival of Lights in San Francisco and around the world. May fear and darkn… https://t.co/pbZEkmVePO',
#               "RT @TeamPelosi: Democracy is on the ballot. Our freedoms are on the ballot. Our economy is on the ballot. Your family's budget is on the ba…",
#               'RT @dccc: Calling all VIPs – volunteers in politics! We need you with us in the fight to #HoldTheHouse. Get involved: https://t.co/cAKl6R72…',
#               'House Republicans said they will force Social Security and Medicare cuts to lift the debt ceiling and put both on t… https://t.co/htQr4J8qq7',
#               "Democracy is on the ballot. Our freedoms are on the ballot. Our economy is on the ballot. Your family's budget is o… https://t.co/f4LcdMZFr3",
#               'RT @TeamPelosi: Republicans have endless dark, special interest money to back candidates who threaten our freedoms and Democracy and would…',
#               "In the last month, I've been to over 20 states and seen on the ground what’s happening among Democratic voters — it… https://t.co/KoAGSEDCOl"],
#              '44774107': ["If you worked for the @ap wouldn't you be ashamed? https://t.co/q8hKicw7ij",
#               'Running on a gun confiscation platform isn’t popular in Texas? https://t.co/qlRnnLIuia',
#               'The idiots who forced the lockdowns on us have no idea how they’ve destroyed the commercial real estate market.'],
#              '816157667882373120': ['📣 Calling student coders!\n\nThe deadline to submit your app to the Congressional App Challenge is next week!\n\nWinnin… https://t.co/NdDd37jOkf',
#               'Happy #Diwali to all those who celebrate on the Central Coast and across the country!\n\nMay your day be filled with… https://t.co/GbejefM1xV'],
#              '1222257180': ['In the Northeast San Fernando Valley alone, 59,700 borrowers are eligible for student loan debt forgiveness. I aske… https://t.co/b8aPL8bRX0',
#               '#HappyDiwali to those celebrating! May you all have a wonderful day filled with joy and light. https://t.co/Eap8NlkUuG',
#               "Had the opportunity to chat with seniors at the Bernardi Senior Center about how I'm serving them in Washington. Fr… https://t.co/Nt5ijCybV6",
#               'RT @POTUS: Exactly one week ago, we launched our application where folks could apply for student loan debt relief. Over 22 million people p…',
#               'Si necesita ayuda para completar una solicitud debido a una discapacidad, traducción o necesidad de un formato de c… https://t.co/nnr70AHqPz',
#               'La lotería de la Lista de Espera de la Sección 8 se abrió el lunes 17 de octubre a las 6 AM (PDT) y permanecerá abi… https://t.co/r3pAwcEbZA',
#               'More resources are available here: https://t.co/J9gjlSdMLI',
#               'If you require assistance completing an application because of a disability, translation or need for a specific com… https://t.co/ace8y5L7YE',
#               'Do you need housing assistance?\n\nThe @HACLA1938 application for the Section 8 Waiting List lottery opened Monday Oc… https://t.co/pVnyFADhEN'],
#              '2543742324': ['RT @giselefetterman: Such a great day kicking off a Latino tour with some favorites: @CepedaFreytiz @RepHoulahan @Manny_Guzman610 @RepCarde…',
#               'RT @HoulahanForPa: Had a great time knocking doors in Reading this past weekend with @Tcardenas, @Manny_Guzman610, @CepedaFreytiz, and @gis…',
#               'My House colleagues and I introduced legislation to make October National Youth Justice Action Month.\n\nWe must draw… https://t.co/qzmatfQIVS',
#               'We need to do everything we can to ensure we win these key swing districts!',
#               'It might have been a Red October in Philly last night, but PA is going to have a BLUE November!\n\nIt was great knock… https://t.co/Cm7nWoQDCx',
#               'I wholeheartedly condemn the vile display of #antisemitism we saw in Los Angeles over the weekend. Antisemitism has… https://t.co/3rY4kIk1HN',
#               'Happy #Diwali to all who celebrate! May the festival of lights brighten your life and fill it with peace, happiness… https://t.co/mKlc8Ju4S2'],
#              '1222586478': ['RT @Angelica4CA: Please join us Wednesday! \nhttps://t.co/Sd7O0VIM4i https://t.co/7bPvVv9Jd1',
#               'East San Fernando Valley vote by Nov 8th! \nCA-29 Includes Arleta, Mission Hills, North Hollywood, Pacoima, Panorama… https://t.co/9kzyJddKZT',
#               'RT @SharonKyle00: All the candidates stood for strong progressive policies. While not all of them made it to the point where they’re on the…'],
#              '193732179': ['RT @CAPAC: Happy #Diwali to everyone celebrating the Festival of Lights! 🪔🪔🪔\n\nRead our CAPAC Members’ statements here: https://t.co/3t6HUgN…'],
#              '14386156': ['I’ve served my country in the Navy -- confronting terrorism in the Middle East. Now it is time for me to serve my c… https://t.co/qaBZm170Lm',
#               'Happy #Diwali. Light over darkness! https://t.co/cN5CWiwBYX',
#               '✅Cerritos\n✅Garden Grove\n✅Fullerton\n✅Placentia\n✅Fountain Valley\n✅Los Alamitos\n✅Brea\n✅Buena Park\n\nA HUGE thank you to… https://t.co/sfZ3CpdLjy'],
#              '1343740146630451200': ['Whether it’s the Small Business Administration, the IRS, the VA, or any other agency, my office is ready to help yo… https://t.co/nkspzxoRkW',
#               '#OC gas prices a year ago = $4.51/gallon\n\nOC gas prices today = $5.67/gallon\n\nThis is the direct result of the Bide… https://t.co/WHIVPt64Cb',
#               'Today is the last day to nominate a Veteran of Distinction! If there is a veteran in your life who you’d like to se… https://t.co/4Y0lFAjqBR'],
#              '1122934522134315009': ['Communist China’s intimidation and infiltration of American schools and institutions is a grave threat. For as long… https://t.co/rpM3C1BEfv',
#               'Wishing all who celebrate a very happy and prosperous Diwali!\xa0#HappyDiwali',
#               'I’m disgusted. Voters deserve a direct answer from Jay Chen NOW.\n\nhttps://t.co/wLx0YMOHqd'],
#              '746481056145018880': ['Here’s your reminder that TODAY is the last day to register to vote!\n\nMake your voice heard! 🗣\nYour vote counts! 🗳… https://t.co/GHFJkPnbgt'],
#              '245451804': ['CalFresh, also known as SNAP, is available to provide relief with groceries for families. Visit… https://t.co/f8yAYkAmHI',
#               'RT @WhiteHouse: Everyone age 5 and older should get the updated COVID-19 vaccine this fall.\n\nSchedule your vaccine today: https://t.co/5SMD…',
#               'Happy Diwali to all those who celebrate! The religious and historical significance of Diwali for Hindus, Jains, Bud… https://t.co/4m2PiNAbz3',
#               'If you are a teacher, nurse, or first responder with federal student loan debt. You may be eligible to receive cred… https://t.co/Vw1kwEKiIo',
#               'Middle-Class Tax Refund payments have been sent out to Californians to help with the high price of gas and cost of… https://t.co/5or3hc5HBg',
#               'RT @KSEE24: "One step closer to reality": The Central Valley’s high-speed rail stations have been approved by the California High-Speed Rai…'],
#              '796736612554117120': ['I recently joined the launch of Monterey Waterkeeper as they embark on a mission to restore fishable, swimmable, an… https://t.co/8k0BhNhyXf',
#               'Last week, I was joined by @SenAlexPadilla and @RepZoeLofgren to announce an additional $82 million in funding for… https://t.co/t7W1095GlD',
#               'The bipartisan More Homes on the Market Act will make it easier for homeowners to earn more from their investment.… https://t.co/MXCFSHx7rU'],
#              '2968007206': ['Big oil is taking advantage of American families by price gouging at the gas pumps while raking in record profits.… https://t.co/9Oc6WHsbNY',
#               'Thanks to U.S. leadership &amp; because #VaccinesWork, polio cases have gone down 99.9% worldwide since 1988. However,… https://t.co/cx50ceEhtz',
#               'I will be joined by Dr. Garen Wintemute @UCDavis and Allison Anderman @Giffords who will offer their expertise.',
#               'With 111 lives lost to gun violence every day in the US, we must come together to discuss commonsense solutions. I’… https://t.co/LmJRSOuyVB'],
#              '1391781110183456773': ["It's time for them to pay their fair share. If you're tired of career politicians join me @ https://t.co/NjfsW02dA3",
#               "Trust me, I know that the price of candy is up--I'm a teacher, and I keep a steady supply of it in my classroom. Bu… https://t.co/B7GYSs3Rfl",
#               "Inflation isn't being driven by the Democrats. Corporations are increasing their $$$ for profit. @GOPleader has no… https://t.co/GWbe4M0Jzn"],
#              '19739126': ['After more than a year of crushing inflation, Democrats still have no plan to solve it. Americans can’t afford Demo… https://t.co/ztWPJFTvlm',
#               'RT @HomelandGOP: 🚨@POTUS’ dangerous open border security policies have allowed an unprecedented number of people whose names appear on the…',
#               'Halloween candy prices have shot up 13% higher compared to last year.\n\nThe Democrats’ tax-and-spend policies have m… https://t.co/dponPtvikS',
#               'RT @WaysandMeansGOP: The Biden Admin is forcing working families to choose between heating their homes and buying essentials.\n\nIt\'s "heat o…',
#               'RT @RepFeenstra: For the last 2 years, House Democrats have wasted trillions of taxpayer dollars advancing their socialist vision for Ameri…',
#               'RT @EdLaborGOP: Part of Republicans’ #CommitmentToAmerica is ensuring schools focus on academic recovery efforts.\n\nRead more from @virginia…',
#               "RT @EdLaborGOP: Can someone fact-check @POTUS' nonsense? Mr. President, you clearly need a refresh so we'll remind you: you bypassed Congre…",
#               'RT @RepMichaelGuest: In 18 months, complete Democrat control in Washington has crippled our economy. Americans deserve an economy that’s st…',
#               'RT @HouseCommerce: To lower prices, create jobs, &amp; reduce emissions, we need to #FlipTheSwitch on AMERICAN energy. \n\n@POTUS and @SecGranhol…',
#               'RT @HouseGOP: WATCH: @RepRutherfordFL on why House Republicans have made a #CommitmentToAmerica:\n\n“Make no mistake: We are in the midst of…',
#               'RT @RepGusBilirakis: As part of our #CommitmenttoAmerica, my colleagues and I will create an economy that is strong by fighting inflation a…',
#               'RT @HouseGOP: House Republicans are committed to an economy that is strong:\n \n👉We will fight inflation &amp; lower the cost of living\n👉We will…',
#               ".@RepAshleyHinson lays it out straight → President Biden and Speaker Pelosi's inflation crisis is impacting the pri… https://t.co/39sFZyyzsw"],
#              '303861808': ['Thanks to the American Canyon Community &amp; Parks Foundation for showing me the proposed site for the Wetlands Eco Ce… https://t.co/zMSPpocTFY',
#               'Jan and I are wishing those celebrating a blessed Diwali. \n\nWe hope that the Diwali lights brighten your day and fi… https://t.co/bek8cJCjt9',
#               'Heartbreaking to hear the news out of St. Louis of a school shooting with multiple people killed and others hospita… https://t.co/4d3HY4eHwG',
#               'TODAY is the last day to enter my Congressional App Challenge!\n\nMake sure you are registered and ready to submit yo… https://t.co/HhsZLJdlBN',
#               'Honored to attend Labath Landing’s ribbon cutting ceremony. The project provides 60 housing units, counseling, &amp; jo… https://t.co/YHNrgcB544',
#               'Every dollar spent on contraceptives saves almost $6 spent on unplanned pregnancies — amounting to $10.5B annually… https://t.co/qkGihDvf8p'],
#              '3612420317': ['Great to visit the Solano County Black Chamber of Commerce and sit down with Tamuri Richardson. Thank you for all t… https://t.co/wfvJWEPFMs',
#               '🚨Today is the last day to register to vote for the November 8th general election!🚨 Check your voter registration st… https://t.co/SAV8iJHAuC',
#               'Enjoyed meeting with Pleasants Valley farmers and ag workers at Soul Food Farm. Thank you to the Pleasants Valley A… https://t.co/79qgUOehRU'],
#              '482713734': ['Our friends who read @hmbreview, we see you! \n"I’ll support her re-election to Congress and I expect a lot of peopl… https://t.co/LxTGdrSngp'],
#              '43740218': ['Today, October 24, is the last day to register to vote to cast your ballot in the November 8 election. Please visit… https://t.co/vB1wjdtzfr',
#               'Today, October 24, is the last day to register to vote to cast your ballot in the November 8 election. Please visit… https://t.co/k4p2VIWDTB',
#               'https://t.co/KYu0UDEeqx',
#               'Happy Diwali to you from all of us. May your life be filled with the Diwali light of joy, health &amp; happiness, abund… https://t.co/D0YCxkylkw'],
#              '816298918468259841': ['Thrilled to see the Phillies headed to the World Series for the first time in over a decade. I caught many games at… https://t.co/EQI0wJgiUb',
#               'We need to pass @RepAdamSchiff’s Support for Iranian Political Prisoners Act, which demands that Iran release all p… https://t.co/mmLyMK8e8J',
#               "I’m deeply moved by the courage of Iranians protesting the regime's barbaric murders of Mahsa Amini and other Irani… https://t.co/hO246AD9Od",
#               'Standing with the Jewish community in Los Angeles, across the country, and around the world. We must condemn antise… https://t.co/LYJAlpmD8W',
#               'Wishing everyone in CA-17 and around the world a happy Diwali, which symbolizes the triumph of good over evil, hope… https://t.co/vLLg5dEwJq',
#               'There is a clear economic choice: Republicans in Congress want to cut taxes for the wealthy while Democrats are wor… https://t.co/AVD1BIehwP'],
#              '771152516': ['RT @mehdirhasan: The UK now has a Hindu prime minister of Indian descent and a Muslim mayor of London of Pakistani descent.',
#               'RT @CarlGuardino: Yes, there are many policy and leadership reasons why I support Cindy Chavez for San Jose’s next Mayor \u2066@chavezformayor\u2069.…',
#               'My grandfather spent years in jail under the British as part of Gandhi’s independence movement. It is remarkable to… https://t.co/R5ek27IDba',
#               'This makes sense @greta . Many digital jobs specifically don’t require a four year degree. https://t.co/d99WrkhOpb',
#               "To me, #Diwali symbolizes the triumph of good over evil, hope over despair, light over darkness. It tells us there'… https://t.co/CTcpqKv8Co",
#               'RT @LathaMangipudi: Wishing everyone  celebrating #DiwaliFestival health, wealth and prosperity. Lighting #Diyas let the light shine bright…',
#               'RT @mehdirhasan: Hey Dems, blame the corporate profiteers and the price gougers for inflation! It has the advantage of being a vote-winner…',
#               'RT @PhillyFanLife: Philadelphia is the greatest sports city in America. \n\n https://t.co/hQ2ZMpEx1y'],
#              '1189206039335276544': ["@RNCResearch Passed by his vote and his VP's",
#               '𝑾𝒊𝒔𝒉𝒊𝒏𝒈 𝒚𝒐𝒖 &amp; 𝒚𝒐𝒖𝒓 𝒇𝒂𝒎𝒊𝒍𝒚 𝒂 𝒗𝒆𝒓𝒚 𝑯𝒂𝒑𝒑𝒚 𝑫𝒊𝒘𝒂𝒍𝒊. 𝑶𝒏 𝒕𝒉𝒊𝒔 𝒃𝒆𝒂𝒖𝒕𝒊𝒇𝒖𝒍 𝒇𝒆𝒔𝒕𝒊𝒗𝒆 𝒐𝒄𝒄𝒂𝒔𝒊𝒐𝒏, 𝑰 𝒑𝒓𝒂𝒚 𝒇𝒐𝒓 𝒚𝒐𝒖𝒓 𝒉𝒆𝒂𝒍𝒕𝒉 𝒂𝒏𝒅 𝒉𝒂𝒑𝒑𝒊… https://t.co/SKWQqvDGVU',
#               'https://t.co/Q3SdahcZqq',
#               '@GOPLeader Time for Nancy &amp; Democratic party to retire.',
#               "@millanpatterson @BrianDahleCA @GavinNewsom It is time to fix California and end one party rule. Let's bring the vo… https://t.co/WLD5AxTeW1"],
#              '38254095': ['RT @CAPublicHealth: Everyone can play a role in preventing infection and keeping yourself and your loved ones safe from infection. https://…'],
#              '169331127': ['Thank you to Elk Grove families that came out to have a cup of coffee with me and thank you to @seat_books for host… https://t.co/8DdO64x3W4'],
#              '88806753': ['RT @SenAlexPadilla: The public lands surrounding the Berryessa Snow Mountain National Monument are\xa0sacred to indigenous communities.\n\xa0\nJoin…',
#               'As chair of the Congressional Sikh caucus I want to wish a happy to Diwali to all celebrating. May you have a bless… https://t.co/6dKSjowF6M',
#               "RT @POTUS: The deficit fell by $1.4 trillion this year.\n\nThat's the largest one-year drop in American history."],
#              '29501253': ['Horrified by the vile antisemitism on display in L.A. this weekend.\n\nTragically it shows the power some hold to amp… https://t.co/xBWcZCH06h'],
#              '272482466': ['I was humbled to be presented with the Shining Star award at Hesperia’s State of the City event last week. Thank yo… https://t.co/J6lXNg4q7D',
#               'The only real solution to our gas price problem is to unleash the power of American energy production, end the bloc… https://t.co/cLTk6kyKFW',
#               'Not only has releasing oil from our strategic reserves failed to solve the gas price problem, it has also put our n… https://t.co/intTaUg3al',
#               'Despite President Biden’s announcement that he will release 15 million more barrels of oil from the Strategic Petro… https://t.co/43nZXaa6Vv'],
#              '1291597452357771264': ['We need to take inflation seriously and stop the reckless deficit spending that is making it worse. I always enjoy… https://t.co/GRzO0Fnq5R'],
#              '1008760087341514758': ['Wishing a happy #Diwali\xa0\xa0 to all who celebrate in #CA23 and across the world!\n\nMay the Festival of Lights bring you… https://t.co/4A5iMG5KjO',
#               '@hana___anah &amp; followed you!',
#               '@hana___anah Absolutely!',
#               'If we want a Congress that fights for working people, we must send working people to Congress.',
#               'Good morning #CA23! ☀️⛰\n\nJust 15 days until #ElectionDay! https://t.co/xhNFtB5QzI',
#               'RT @marwilliamson: In 2020 I launched a project endorsing and fundraising for progressive candidates around the country. Since its inceptio…',
#               'Everyone at canvass time agrees 🤷🏻\u200d♂️ https://t.co/TIArFdav29 https://t.co/w0v0E3SUmQ'],
#              '2371339658': ['🚨Heads up Angelenos! Today is the last day to register online or by mail in California.\n\nMake sure your voice is he… https://t.co/G7BPKLTYpp',
#               'Started off my day at @LAHelloStranger for a roundtable discussion with entrepreneurs in #LittleTokyo!\n\nSmall busin… https://t.co/AUlYohKQGH',
#               'I strongly condemn the antisemitic statements displayed on the 405 this weekend. We must never tolerate this danger… https://t.co/WdBrgUBXAv',
#               'Today marks the start of #Diwali , also known as the Festival of Lights!\n\nWishing all those celebrating today peace… https://t.co/m8WTyG3YzK'],
#              '818276294328582145': ['@SophiaCRome @GillForLA @kennethmejiaLA Thank you!! Let’s go!! 🙏🙌❤️',
#               'It’s an honor to be endorsed by @fialosangeles and its members who are proactive leaders and activists in the commu… https://t.co/X7ojA8jpNy',
#               'RT @SharonKyle00: All the candidates stood for strong progressive policies. While not all of them made it to the point where they’re on the…',
#               'RT @theglowingstars: progressive campaigns are changing the billboard game 😎',
#               'RT @returnofthebern: 2022 General Election Endorsements (THREAD)\n\n#CA05 @mjbarkl\n\n#CA15 @davidcanepa\n\n#CA16 @rishikumar1\n\n#CA20 @MarisaWood…',
#               'RT @nicole_d14: Lizzo said no more status quo! It’s BEEN time for bold change like @DavidKimForCA and @kennethmejiaLA 🔥',
#               'RT @marwilliamson: All the candidates stood for strong progressive policies. While not all of them made it to the point where they’re on th…'],
#              '1071102246': ['America: Why is our democracy at risk? \n\nWhite Christian Nationalists: https://t.co/na8UTIPfah',
#               '#HappyDiwali to those celebrating! May you all have a wonderful day filled with joy and light. https://t.co/CoFTGA7dVA',
#               '🚨Reminder🚨 \nToday is the last day to register by mail or online to vote in California.\n\nCheck your voter status her… https://t.co/cEXhyWLN6M',
#               'RT @pvmarincounty: Yesterday at the Marin Communications Forum w Congressman @RepHuffman . El día de ayer en el Foro de comunicaciones de M…',
#               'RT @PerformingStars: Honored to provide a tour for Congressman Jared Huffman of the Marin City Historical Exhibits at the Bartolini Gallery…'],
# ...
#               'RT @shannonrwatts: The school in St. Louis had metal detectors. Police said the doors were locked. There were armed guards inside the schoo…',
#               'RT @RepCicilline: With the support of $81M in federal funding, today we broke ground on a new major life sciences development which will ho…',
#               'I just voted early and you can too! You can vote early in person at your city or town hall or other designated loca… https://t.co/220IW8JFDx'],
#              '15838320': ["Congrats to #TeamTreasury's very own, Carol Aguasvivas, who runs our Unclaimed Property Division.\n\nShe was recently… https://t.co/681UuwuG5o",
#               'Our Unclaimed Property team has traveled all over the state helping to reunite Rhode Islanders with their missing m… https://t.co/6qzyjqVDRD'],
#              '1434052620': ['The people who wrote this tweet are the people my opponent Allan Fung thinks should be in control of Congress. https://t.co/T058Pu3DNL',
#               'In Congress, I will fight to codify a woman’s right to choose into federal law. A woman’s health care decisions sho… https://t.co/Htl0TqdkGn'],
#              '878984646': ['Always a pleasure to celebrate faith and family alongside our Cambodian neighbors at the Dhamagosnaram Temple in Cr… https://t.co/OgevEATVlv',
#               'RT @JohnDePetroshow: Republicans Target Deep-Blue New England in Midterms - WSJ. Mr. Donabed, 62, a high-school teacher, said he usually vo…'],
#              '1080222360643485698': ['4th graders at Diamond Path Elementary in Apple Valley asked me to drop by their classes sometime to talk about wha… https://t.co/DY00Xr9ikX',
#               'I got a chance to stop by and chat with @tchabitat at one of their projects in Prior Lake where my staff was volunt… https://t.co/89Eb8NXBeA',
#               'Big Pharma needs a big wake-up call. That’s why I made sure the Inflation Reduction Act included my provision to gi… https://t.co/C4Jyo2oF7y'],
#              '411861905': ['Mayor Williams is a true leader for Savage, and it’s been great working with her on infrastructure projects that wi… https://t.co/69DBjKFx2L',
#               'Today marks four months since SCOTUS gave states the power to ban abortion without exceptions.\n\n@KistnerCongress ag… https://t.co/VH8YjWkNr7',
#               'I helped deliver critical investments to save Minnesotans money on their energy bills &amp; accelerate our transition t… https://t.co/LXXgQ6AoDz'],
#              '1211735619333808128': ['🚨🚨New Ad🚨🚨\n\nOur lives are dangerous and unaffordable as a result of @JoeBiden and @AngieCraigMN’s policies. \n\nIf yo… https://t.co/yHz0cI28YR',
#               "RT @michaelgwaltz: I'm proud to support a new generation of veterans through Front Line Patriots to get our country back on track.\n\nWe are…",
#               'RT @GrageDustin: Elect @KistnerCongress.\n\nLower gas prices.',
#               'This you @AngieCraigMN? #MN02 https://t.co/yKopKIOMLv https://t.co/gUz4q9dm9F',
#               'RT @IAPolls2022: 🚨 RCP HOUSE RATING CHANGES\n\n✅ 5 Races shift Toward Republicans\n\nRCP HOUSE FORECAST \n⦿ Republicans — 225\n⦿ Democrats — 175…'],
#              '1061310112013434882': ['This isn’t Berlin in 1938.\n\nThis is Los Angeles in 2022.\n\nIt’s time to attack the disease of anti-Semitism. And fas… https://t.co/5pIswF1yBz'],
#              '39894447': ['Opportunity and self-sufficiency begins with public support of entrepreneurship - particularly in rural and underse… https://t.co/6fppVuUUCn',
#               'Another massive turnout today in Edina. Knock those doors, make those calls, and extend those invitations. Sixteen… https://t.co/D6uxqvYjHQ'],
#              '1450529402211688448': ['Minnesotans in the 3rd District, let’s Turn the Ship Around together. https://t.co/gXzyUp3HRr',
#               'https://t.co/oMzQhnb96i',
#               'Another clear lie from @RepDeanPhillips .  Don’t take my word for it, just watch @deanbphillips , @SpeakerPelosi ,… https://t.co/BTcyjoVaDE',
#               'Don’t miss the forest for the trees.\n\nDebate Night on @KSTP commercial sums it all up. https://t.co/OmHGXx26jE',
#               '.@MNPoliceAssn ,I agree, disappointing.Speaking of disappointing, could you explain to rank &amp; file Officers you rep… https://t.co/d7EMik0Ivk'],
#              '516880804': ['#UnitedNationsDay celebrates the anniversary of the official creation of the @UN. Let’s recommit to the goals of pe… https://t.co/WnUni8bgFT',
#               'Happy #Diwali to all those celebrating the festival of lights! May our futures be brightened by the triumph of good… https://t.co/OQgHhgCHYr'],
#              '164414525': ['RT @leighfinke: I’m at the park with the kids, enjoying this last little burst of warm Sunday.\n\nThinking, we are fighting for something big…',
#               'RT @LizLeeMN: Thanks to our door knock crew for closing out a fantastic first  weekend of GOTV for @keithellison @Tim_Walz @peggyflanagan @…',
#               'RT @reprickhansen: Remembering https://t.co/evoE6AIjwo'],
#              '1082334352711790593': ['As Republicans continue to attack President Biden’s student debt action, please continue to apply for student debt… https://t.co/ZrHh3xeOps',
#               'Happy Diwali to all those celebrating in Minnesota and beyond! May it be filled with light, love, and joy.',
#               'This Thursday at 6pm CT, our office will host a town hall in Richfield to discuss our ongoing work for the 5th Dist… https://t.co/AAFb7u0VLX'],
#              '783792992': ['This is sickening antisemitism.\n\nThis toxic hate is a direct threat to our Jewish neighbors and families. We all ha… https://t.co/aiMMhed2GW',
#               'RT @OdessaKellyTN: 🚨ENDORSEMENT ALERT🚨\n\nThe 3 most courageous Black women in Congress have officially endorsed our people-powered campaign!…',
#               'RT @katecma: You know, @Ilhan always proposes foreign policy that is both pragmatic and deeply transformative:\n\n"Only support for democrati…',
#               'RT @JosephGeev: Dark Money and conservative attacks are tightening key races. But we have a blueprint to build Progressive power. Join us o…',
#               'RT @mehdirhasan: Hey Dems, blame the corporate profiteers and the price gougers for inflation! It has the advantage of being a vote-winner…',
#               "RT @MFT59: Yesterday was a blast! We hosted a rally at the office with Ilhan Omar and so many other inspiring candidates in this year's ele…"],
#              '1416469317625974787': ['In the economy Ilhan Omar and others have left us with, you are paying more and getting less! This is not fair for… https://t.co/WJswi3SlOZ'],
#              '2914515430': ['President Biden has drained the SPR by nearly 40%, 200 million barrels, in less than two years.\n\xa0\nThat is more than… https://t.co/mCuhIIO8bQ',
#               "RT @FinancialCmte: Under Democrats' one-party rule:\n📉 Real wages are falling\n📈 Gas and grocery prices are skyrocketing\n❌ Supply chains are…",
#               'Violent crime is surging across the country.\n\nDemocrats have normalized this insanity, but Republicans are committe… https://t.co/GlmtNOfO2B',
#               'Real wages are falling, savings accounts are collapsing, household debt has skyrocketed, and our economy is in a re… https://t.co/zFBuGNGDqL'],
#              '72431423': ['In 15 days we are going to #FirePelosi',
#               'Keep up the great work @JenRuthGreen! https://t.co/VPTxe4Xhms',
#               'New Yorkers are sick of Democrats’ pro-criminal agenda. https://t.co/xMNCzuKUCr'],
#              '1387824293124395008': ["RT @Buckmeier4MN: Let's step up and support our school districts since they are the backbone of our communities. I want to move our schools…",
#               'RT @NationalNOWPAC: NOW PAC is proud to endorse @hendricks2022  in MN-06 who has exemplified consistent dedication to our core values, prom…',
#               "Thanks to all who have put my campaign sign in their yards throughout Minnesota's 6th.👏 https://t.co/d1bZZiaRDy",
#               "My campaign's goal today is to get to 5,000 followers. 366 to go. Can you please RT and ask your friends to follow… https://t.co/aSyWG3Bm2C",
#               '@SanentT Good morning:)',
#               "@SanentT Hi! I'm Jeanne Hendricks, mom, nurse and the Democratic nominee for U.S. Congress in MN-CD-6 running to de… https://t.co/LFCMKg0fzn",
#               "RT @SanentT: 💙💙 Monday follow back party. 💙💙\n💙💙 This is what you do if you're blue. 💙💙\n❤️THIS doesn't work if you don't do the following.❤️…"],
#              '1344375287484723205': ['Republicans have a plan to restock our shelves &amp; get people the goods they need:\n\n✅Move supply chains away from Chi… https://t.co/w5tCWC5UUq'],
#              '1075830599007510535': ['Compare the prices of your daily necessities in 2020 to now. Almost everything has skyrocketed.\n\nInflation is a tax… https://t.co/SLCpmwiolo'],
#              '883069589722198018': ["While door knocking in Cloquet, @dotseth_jeff and I had the chance to greet one of our nation's heroes - Dale who s… https://t.co/5xvQR2IAZO",
#               'Starting the day with the best and brightest at Cloquet High School with @dotseth_jeff. Inflation and high gas pric… https://t.co/GYlIcp9Sha',
#               "Under the public safety failures of Tim Walz and Keith Ellison, violent crime continues to rise in Minnesota. They'… https://t.co/hn3LmZt8FC"],
#              '3008735749': ['Once again, Stauber fails to respond to his constituents. #noresponse https://t.co/OkZpHnyTJi',
#               "Debate Alert! This evening I will be debating Stauber in Brainerd at Madden's Resort on Gull Lake from 6:30pm-8:00p… https://t.co/e2JCxo8IPo"],
#              '18137749': ['The American Rescue Plan was a lifeline for over 5,000 child care programs in Maryland.\xa0Still, many\xa0families are st… https://t.co/Cfdb5Wf1XH'],
#              '1080573351914061825': ['✅ Community Project Funding delivered to @alleganycollgmd’s Community Theatre. This renovation means investing in t… https://t.co/53uFb0zLKL',
#               'Family-owned businesses are vital to our economy, and the National Jet Company is no exception. This business benef… https://t.co/BbxFG7LBKa',
#               "In Allegany County, I'm working hard to bring home $7 million to fix the Fayette Street Bridge, renovate the Barton… https://t.co/3bcbUGVm1h",
#               'I was honored to speak at the Maryland Rural Health Care Conference. We are developing real solutions to help serve… https://t.co/ACOKzK6Pv4',
#               "#ICYMI I'm working to deliver $30 million in #CommunityProjectFunding to invest in our local medical centers, infra… https://t.co/icVTCskvSq",
#               'Happy birthday to my friend and fellow Marylander, @RepKweisiMfume! I always enjoy working alongside you on… https://t.co/tWrDZwHdnt',
#               'Happy #Diwali to all Marylanders celebrating! I hope you have a wonderful day filled with joy and light. https://t.co/1QUcrxQfIi',
#               'This week is #CommunityProjectFunding week for Team Trone! By partnering with our local leaders, we can deliver vit… https://t.co/OLO8Zvs1qv'],
#              '105251964': ['RT @BPUnion: If you want a secure border, if you’re tired of seeing millions illegally breaking into our country, if you think immigration…',
#               "This week we're going to play a game called Game of Trones, where we ask a question about David Trone's record and… https://t.co/5mrNin4X2M",
#               'Senator Cruz Rally for Delegate Parrott with former Congressman Bartlett and Sheriff Chuck Jenkins -… https://t.co/XsCN2I7gUI',
#               'RT @laurenboebert: Nancy Pelosi wants to “change the subject” when it comes to inflation.\n\nWhat we actually need to do is change the leader…',
#               '@FredFleitz thank you for your support, tell everyone you know to vote! as you can see this election is going to be so very close!'],
#              '364415553': ['To all who celebrate #Diwali, I hope you have a wonderful day of festivities. As we celebrate the festival of light… https://t.co/5YrDCTV8t7'],
#              '1023028026106421248': ['Join me today on @MiddayWYPR at 12:30 pm. I’ll tell you how I plan to work for YOU https://t.co/VGZEhZGGgx',
#               'She picked up a #rubikscube for the 1st time this week. Now shes solving it in⬇️ 2 MINUTES 😱 Every kid deserves the… https://t.co/CAIQw6sPnn'],
#              '1276209702322438148': ['RT @BmoreCityDOT: 7th District @RepKweisiMfume  said, "I walked the streets surrounding the ‘Highway to Nowhere\' long before becoming a mem…',
#               '@RepDavidTrone Thanks David, the feelings are quite mutual. Thanks for all you do for the people of Maryland and fo… https://t.co/MZH6DWiMDz'],
#              '305620929': ["Here's a big one: just announced nearly $3 MILLION in @TheJusticeDept funds to help @MDSP investigate and shut down… https://t.co/RqItNGJ4Wl",
#               'Proud to join my colleagues in announcing a $900K federal grant to a great #Baltimore nonprofit that helps women su… https://t.co/HLDs1gzPIr',
#               'Thanks to U.S. leadership &amp; because #VaccinesWork, polio cases have gone down 99.9% worldwide since 1988. But recen… https://t.co/JdYbj28Pkm',
#               'For those celebrating throughout #MD02, I hope the #Diwali lights brighten your life and fill your day with happine… https://t.co/ZpHo5Z6RnN'],
#              '960962340': ['RT @Jim_Jordan: Speaker Pelosi:\n\n“When I hear people talk about inflation . . . we have to change that subject.”\n\nDemocrats can run from th…'],
#              '115149062': ['If you only engage with people who agree with you on everything, you’re not doing your job as a representative. It’… https://t.co/gjMTFyoJsw'],
#              '22012091': ['I join in wishing all those celebrating tonight in #MD05 and across the world a #HappyDiwali and continuing health,… https://t.co/nfzLdCoSYB',
#               'Happy birthday to @RepMoulton from #MA06. Thank you for your service to our country as a U.S. Marine and for bringi… https://t.co/5w7dt70rVb',
#               'Wishing a happy birthday to my friend @BradSherman from #CA30, a strong voice in promoting American values abroad a… https://t.co/VbYBR4T1tq',
#               'I am concerned by the immigration processing issues at USCIS in Baltimore, and joined my colleagues in urging the D… https://t.co/UMJQa2vCl9',
#               'I am deeply dismayed by the news of another school shooting, this time at Central Visual and Performing Arts High S… https://t.co/NcESr2acH7',
#               'I joined the Maryland Delegation in urging the Biden Administration to fund efforts that will reconnect communities… https://t.co/ZRbngn9sxz',
#               'On January 6th, 2021, former President Trump incited a violent riot at the Capitol in an attempt to overturn a free… https://t.co/GUApyjDq8R'],
#              '1026649952': ["Thank you to @LPFsports, a phenomenal organization that I've partnered with over the past four years to supply gear… https://t.co/TR3agOFJlK",
#               "It's full! Collected donated gear to give to 22 new players wanting to try ice hockey.\xa0\n\nNothing beats giving back… https://t.co/wperedP3hq",
#               'Fine, let\'s talk about the "cost of living" that has been crushing families thanks to Pelosi and Hoyer\'s reckless s… https://t.co/9QWObI8MMl'],
#              '806906355214852096': ['Wishing a Diwali full of peace, love, family and friends to all celebrating!',
#               'Thanks to U.S. leadership and vaccination efforts, polio cases have gone down 99.9% worldwide since 1988. This… https://t.co/wtbZwc1j0v'],
#              '174446037': ['Thank you all for coming out to support my campaign and be a part of this amazing show focused on Faith, Family, an… https://t.co/igwLfCECTc'],
#              '867495243482058755': ['Unlike the majority of Iowans who support abortion, Zach Nunn wants to ban all abortions, no exceptions.\xa0… https://t.co/BkIlS9HPK6']})

# %%
user_to_tweets = f"{outdir}/table.by.user.pkl"
